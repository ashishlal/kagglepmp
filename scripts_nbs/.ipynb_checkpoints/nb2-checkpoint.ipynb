# %%
# https://www.kaggle.com/artgor/brute-force-feature-engineering
# feature engg

# %%
import numpy as np
import pandas as pd
import os

from tqdm import tqdm_notebook
from sklearn.preprocessing import StandardScaler
from sklearn.svm import NuSVR, SVR
from sklearn.metrics import mean_absolute_error
pd.options.display.precision = 15

import lightgbm as lgb
import xgboost as xgb
import time
import datetime
from catboost import CatBoostRegressor
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import StratifiedKFold, KFold, RepeatedKFold
from sklearn import metrics
from sklearn import linear_model
import gc
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

from IPython.display import HTML
import json
import altair as alt

import networkx as nx
import matplotlib.pyplot as plt
# %matplotlib inline

alt.renderers.enable('notebook')

from artgor_utils import *

# %%
def train_model_regression2(X, X_test, y, params, folds, model_type='lgb', eval_metric='mae', columns=None, plot_feature_importance=False, model=None,
                               verbose=10000, early_stopping_rounds=200, n_estimators=50000):
    """
    A function to train a variety of regression models.
    Returns dictionary with oof predictions, test predictions, scores and, if necessary, feature importances.
    
    :params: X - training data, can be pd.DataFrame or np.ndarray (after normalizing)
    :params: X_test - test data, can be pd.DataFrame or np.ndarray (after normalizing)
    :params: y - target
    :params: folds - folds to split data
    :params: model_type - type of model to use
    :params: eval_metric - metric to use
    :params: columns - columns to use. If None - use all columns
    :params: plot_feature_importance - whether to plot feature importance of LGB
    :params: model - sklearn model, works only for "sklearn" model type
    
    """
    columns = X.columns if columns is None else columns
    X_test = X_test[columns]
    
    # to set up scoring parameters
    metrics_dict = {'mae': {'lgb_metric_name': 'mae',
                        'catboost_metric_name': 'MAE',
                        'sklearn_scoring_function': metrics.mean_absolute_error},
                    'group_mae': {'lgb_metric_name': 'mae',
                        'catboost_metric_name': 'MAE',
                        'scoring_function': group_mean_log_mae},
                    'mse': {'lgb_metric_name': 'mse',
                        'catboost_metric_name': 'MSE',
                        'sklearn_scoring_function': metrics.mean_squared_error}
                    }

    
    result_dict = {}
    
    # out-of-fold predictions on train data
    oof = np.zeros(len(X))
    
    # averaged predictions on train data
    prediction = np.zeros(len(X_test))
    
    # list of scores on folds
    scores = []
    feature_importance = pd.DataFrame()
    
    # split and train on folds
    for fold_n, (train_index, valid_index) in enumerate(folds.split(X)):
        if fold_n > 0:
            continue
        print(f'Fold {fold_n + 1} started at {time.ctime()}')
        if type(X) == np.ndarray:
            X_train, X_valid = X[columns][train_index], X[columns][valid_index]
            y_train, y_valid = y[train_index], y[valid_index]
        else:
            X_train, X_valid = X[columns].iloc[train_index], X[columns].iloc[valid_index]
            y_train, y_valid = y.iloc[train_index], y.iloc[valid_index]
            
        if model_type == 'lgb':
            model = lgb.LGBMRegressor(**params, n_estimators = n_estimators, n_jobs = -1)
            model.fit(X_train, y_train, 
                    eval_set=[(X_train, y_train), (X_valid, y_valid)], eval_metric=metrics_dict[eval_metric]['lgb_metric_name'],
                    verbose=verbose, early_stopping_rounds=early_stopping_rounds)
            
            y_pred_valid = model.predict(X_valid)
            y_pred = model.predict(X_test, num_iteration=model.best_iteration_)
            
        if model_type == 'xgb':
            train_data = xgb.DMatrix(data=X_train, label=y_train, feature_names=X.columns)
            valid_data = xgb.DMatrix(data=X_valid, label=y_valid, feature_names=X.columns)

            watchlist = [(train_data, 'train'), (valid_data, 'valid_data')]
            model = xgb.train(dtrain=train_data, num_boost_round=20000, evals=watchlist, early_stopping_rounds=200, verbose_eval=verbose, params=params)
            y_pred_valid = model.predict(xgb.DMatrix(X_valid, feature_names=X.columns), ntree_limit=model.best_ntree_limit)
            y_pred = model.predict(xgb.DMatrix(X_test, feature_names=X.columns), ntree_limit=model.best_ntree_limit)
        
        if model_type == 'sklearn':
            model = model
            model.fit(X_train, y_train)
            
            y_pred_valid = model.predict(X_valid).reshape(-1,)
            score = metrics_dict[eval_metric]['sklearn_scoring_function'](y_valid, y_pred_valid)
            print(f'Fold {fold_n}. {eval_metric}: {score:.4f}.')
            print('')
            
            y_pred = model.predict(X_test).reshape(-1,)
        
        if model_type == 'cat':
            model = CatBoostRegressor(iterations=20000,  eval_metric=metrics_dict[eval_metric]['catboost_metric_name'], **params,
                                      loss_function=metrics_dict[eval_metric]['catboost_metric_name'])
            model.fit(X_train, y_train, eval_set=(X_valid, y_valid), cat_features=[], use_best_model=True, verbose=False)

            y_pred_valid = model.predict(X_valid)
            y_pred = model.predict(X_test)
        
        oof[valid_index] = y_pred_valid.reshape(-1,)
        if eval_metric != 'group_mae':
            scores.append(metrics_dict[eval_metric]['sklearn_scoring_function'](y_valid, y_pred_valid))
        else:
            scores.append(metrics_dict[eval_metric]['scoring_function'](y_valid, y_pred_valid, X_valid['type']))

        prediction += y_pred    
        
        if model_type == 'lgb' and plot_feature_importance:
            # feature importance
            fold_importance = pd.DataFrame()
            fold_importance["feature"] = columns
            fold_importance["importance"] = model.feature_importances_
            fold_importance["fold"] = fold_n + 1
            feature_importance = pd.concat([feature_importance, fold_importance], axis=0)

    prediction /= folds.n_splits
    
#     print('CV mean score: {0:.4f}, std: {1:.4f}.'.format(np.mean(scores), np.std(scores)))
    
    result_dict['oof'] = oof
    result_dict['prediction'] = prediction
    result_dict['scores'] = scores
    
    if model_type == 'lgb':
        if plot_feature_importance:
            feature_importance["importance"] /= folds.n_splits
            cols = feature_importance[["feature", "importance"]].groupby("feature").mean().sort_values(
                by="importance", ascending=False)[:50].index

            best_features = feature_importance.loc[feature_importance.feature.isin(cols)]

            plt.figure(figsize=(16, 12));
            sns.barplot(x="importance", y="feature", data=best_features.sort_values(by="importance", ascending=False));
            plt.title('LGB Features (avg over folds)');
            
            result_dict['feature_importance'] = feature_importance
        
    return result_dict

# %%
file_folder = '../data'
train = pd.read_csv(f'{file_folder}/train.csv')
test = pd.read_csv(f'{file_folder}/test.csv')
sub = pd.read_csv(f'{file_folder}/sample_submission.csv')
structures = pd.read_csv(f'{file_folder}/structures.csv')

# %%
from tqdm import tqdm_notebook as tqdm
atomic_radius = {'H':0.38, 'C':0.77, 'N':0.75, 'O':0.73, 'F':0.71} # Without fudge factor

fudge_factor = 0.05
atomic_radius = {k:v + fudge_factor for k,v in atomic_radius.items()}
print(atomic_radius)

electronegativity = {'H':2.2, 'C':2.55, 'N':3.04, 'O':3.44, 'F':3.98}

#structures = pd.read_csv(structures, dtype={'atom_index':np.int8})

atoms = structures['atom'].values
atoms_en = [electronegativity[x] for x in tqdm(atoms)]
atoms_rad = [atomic_radius[x] for x in tqdm(atoms)]

structures['EN'] = atoms_en
structures['rad'] = atoms_rad

display(structures.head())
# Out:
# {'H': 0.43, 'C': 0.8200000000000001, 'N': 0.8, 'O': 0.78, 'F': 0.76}
# HBox(children=(IntProgress(value=0, max=2358657), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=2358657), HTML(value='')))
#       molecule_name  atom_index atom             x             y  \
# 0  dsgdb9nsd_000001           0    C -0.0126981359  1.0858041580
# 1  dsgdb9nsd_000001           1    H  0.0021504160 -0.0060313176
# 2  dsgdb9nsd_000001           2    H  1.0117308430  1.4637511620
# 3  dsgdb9nsd_000001           3    H -0.5408150690  1.4475266140
# 4  dsgdb9nsd_000001           4    H -0.5238136345  1.4379326440
#
#               z    EN   rad
# 0  0.0080009958  2.55  0.82
# 1  0.0019761204  2.20  0.43
# 2  0.0002765748  2.20  0.43
# 3 -0.8766437152  2.20  0.43
# 4  0.9063972942  2.20  0.43

# %%
i_atom = structures['atom_index'].values
p = structures[['x', 'y', 'z']].values
p_compare = p
m = structures['molecule_name'].values
m_compare = m
r = structures['rad'].values
r_compare = r

source_row = np.arange(len(structures))
max_atoms = 28

bonds = np.zeros((len(structures)+1, max_atoms+1), dtype=np.int8)
bond_dists = np.zeros((len(structures)+1, max_atoms+1), dtype=np.float32)

print('Calculating the bonds')

for i in tqdm(range(max_atoms-1)):
    p_compare = np.roll(p_compare, -1, axis=0)
    m_compare = np.roll(m_compare, -1, axis=0)
    r_compare = np.roll(r_compare, -1, axis=0)
    
    mask = np.where(m == m_compare, 1, 0) #Are we still comparing atoms in the same molecule?
    dists = np.linalg.norm(p - p_compare, axis=1) * mask
    r_bond = r + r_compare
    
    bond = np.where(np.logical_and(dists > 0.0001, dists < r_bond), 1, 0)
    
    source_row = source_row
    target_row = source_row + i + 1 #Note: Will be out of bounds of bonds array for some values of i
    target_row = np.where(np.logical_or(target_row > len(structures), mask==0), len(structures), target_row) #If invalid target, write
    
    source_atom = i_atom
    target_atom = i_atom + i + 1 #Note: Will be out of bounds of bonds array for some values of i
    target_atom = np.where(np.logical_or(target_atom > max_atoms, mask==0), max_atoms, target_atom) #If invalid target, write to dummy col
    
    bonds[(source_row, target_atom)] = bond
    bonds[(target_row, source_atom)] = bond
    bond_dists[(source_row, target_atom)] = dists
    bond_dists[(target_row, source_atom)] = dists

bonds = np.delete(bonds, axis=0, obj=-1) #Delete dummy row
bonds = np.delete(bonds, axis=1, obj=-1) #Delete dummy col
bond_dists = np.delete(bond_dists, axis=0, obj=-1) #Delete dummy row
bond_dists = np.delete(bond_dists, axis=1, obj=-1) #Delete dummy col

print('Counting and condensing bonds')

bonds_numeric = [[i for i,x in enumerate(row) if x] for row in tqdm(bonds)]
bond_lengths = [[dist for i,dist in enumerate(row) if i in bonds_numeric[j]] for j,row in enumerate(tqdm(bond_dists))]
bond_lengths_mean = [ np.mean(x) for x in bond_lengths]
n_bonds = [len(x) for x in bonds_numeric]

#bond_data = {'bond_' + str(i):col for i, col in enumerate(np.transpose(bonds))}
#bond_data.update({'bonds_numeric':bonds_numeric, 'n_bonds':n_bonds})

bond_data = {'n_bonds':n_bonds, 'bond_lengths_mean': bond_lengths_mean }
bond_df = pd.DataFrame(bond_data)
structures = structures.join(bond_df)
display(structures.head(20))
# Out:
# Calculating the bonds
# HBox(children=(IntProgress(value=0, max=27), HTML(value='')))
# Counting and condensing bonds
# HBox(children=(IntProgress(value=0, max=2358657), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=2358657), HTML(value='')))
#        molecule_name  atom_index atom             x             y  \
# 0   dsgdb9nsd_000001           0    C -0.0126981359  1.0858041580
# 1   dsgdb9nsd_000001           1    H  0.0021504160 -0.0060313176
# 2   dsgdb9nsd_000001           2    H  1.0117308430  1.4637511620
# 3   dsgdb9nsd_000001           3    H -0.5408150690  1.4475266140
# 4   dsgdb9nsd_000001           4    H -0.5238136345  1.4379326440
# 5   dsgdb9nsd_000002           0    N -0.0404260543  1.0241077530
# 6   dsgdb9nsd_000002           1    H  0.0172574639  0.0125452063
# 7   dsgdb9nsd_000002           2    H  0.9157893661  1.3587451950
# 8   dsgdb9nsd_000002           3    H -0.5202777357  1.3435321260
# 9   dsgdb9nsd_000003           0    O -0.0343604951  0.9775395708
# 10  dsgdb9nsd_000003           1    H  0.0647664923  0.0205721989
# 11  dsgdb9nsd_000003           2    H  0.8717903737  1.3007924050
# 12  dsgdb9nsd_000004           0    C  0.5995394918  0.0000000000
# 13  dsgdb9nsd_000004           1    C -0.5995394918  0.0000000000
# 14  dsgdb9nsd_000004           2    H -1.6616385860  0.0000000000
# 15  dsgdb9nsd_000004           3    H  1.6616385860  0.0000000000
# 16  dsgdb9nsd_000005           0    C -0.0133239314  1.1324657150
# 17  dsgdb9nsd_000005           1    N  0.0023107217 -0.0191585871
# 18  dsgdb9nsd_000005           2    H -0.0278026991  2.1989492960
# 19  dsgdb9nsd_000007           0    C -0.0187040036  1.5255820150
#
#                z    EN   rad  bond_lengths_mean  n_bonds
# 0   0.0080009958  2.55  0.82  1.091949701309204        4
# 1   0.0019761204  2.20  0.43  1.091953039169312        1
# 2   0.0002765748  2.20  0.43  1.091951608657837        1
# 3  -0.8766437152  2.20  0.43  1.091946363449097        1
# 4   0.9063972942  2.20  0.43  1.091947555541992        1
# 5   0.0625637998  3.04  0.80  1.017194986343384        3
# 6  -0.0273771593  2.20  0.43  1.017189979553223        1
# 7  -0.0287577581  2.20  0.43  1.017187237739563        1
# 8  -0.7755426124  2.20  0.43  1.017207860946655        1
# 9   0.0076015923  3.44  0.78  0.962106823921204        2
# 10  0.0015346341  2.20  0.43  0.962106823921204        1
# 11  0.0006931336  2.20  0.43  0.962106823921204        1
# 12  1.0000000000  2.55  0.82  1.130589008331299        2
# 13  1.0000000000  2.55  0.82  1.130589008331299        2
# 14  1.0000000000  2.20  0.43  1.062099099159241        1
# 15  1.0000000000  2.20  0.43  1.062099099159241        1
# 16  0.0082758861  2.55  0.82  1.109173059463501        2
# 17  0.0019287305  3.04  0.80  1.151747941970825        1
# 18  0.0141537903  2.20  0.43  1.066598057746887        1
# 19  0.0104328082  2.55  0.82  1.203627109527588        4

# %%
def map_atom_info(df, atom_idx):
    df = pd.merge(df, structures, how = 'left',
                  left_on  = ['molecule_name', f'atom_index_{atom_idx}'],
                  right_on = ['molecule_name',  'atom_index'])
    
    df = df.drop('atom_index', axis=1)
    df = df.rename(columns={'atom': f'atom_{atom_idx}',
                            'x': f'x_{atom_idx}',
                            'y': f'y_{atom_idx}',
                            'z': f'z_{atom_idx}'})
    return df

# %%
train = map_atom_info(train, 0)
train = map_atom_info(train, 1)

test = map_atom_info(test, 0)
test = map_atom_info(test, 1)

# %%
train_p_0 = train[['x_0', 'y_0', 'z_0']].values
train_p_1 = train[['x_1', 'y_1', 'z_1']].values
test_p_0 = test[['x_0', 'y_0', 'z_0']].values
test_p_1 = test[['x_1', 'y_1', 'z_1']].values

train['dist'] = np.linalg.norm(train_p_0 - train_p_1, axis=1)
test['dist'] = np.linalg.norm(test_p_0 - test_p_1, axis=1)
train['dist_x'] = (train['x_0'] - train['x_1']) ** 2
test['dist_x'] = (test['x_0'] - test['x_1']) ** 2
train['dist_y'] = (train['y_0'] - train['y_1']) ** 2
test['dist_y'] = (test['y_0'] - test['y_1']) ** 2
train['dist_z'] = (train['z_0'] - train['z_1']) ** 2
test['dist_z'] = (test['z_0'] - test['z_1']) ** 2

train['dx'] = (train['x_0'] - train['x_1'])
test['dx'] = (test['x_0'] - test['x_1'])
train['dy'] = (train['y_0'] - train['y_1'])
test['dy'] = (test['y_0'] - test['y_1'])
train['dz'] = (train['z_0'] - train['z_1'])
test['dz'] = (test['z_0'] - test['z_1'])

train['r']  = np.sqrt(train['dx']**2+train['dy']**2)
test['r']  = np.sqrt(test['dx']**2+test['dy']**2)

train['phi']  = np.arctan2(train['dy'],train['dx'])
test['phi']  = np.arctan2(test['dy'],test['dx'])

train['phi_deg']  = np.degrees(np.arctan2(train['dy'],train['dx']))
test['phi_deg']  = np.degrees(np.arctan2(test['dy'],test['dx']))

train['z1'] = train['dz']/train['dist']
test['z1'] = test['dz']/test['dist']

train['z2'] = train['dz']/train['r']
test['z2'] = test['dz']/test['r']

train['theta']  = np.arctan2(train['r'],train['dz'])
test['theta']  = np.arctan2(test['r'],test['dz'])

train['theta_deg']  = np.degrees(np.arctan2(train['r'],train['dz']))
test['theta_deg']  = np.degrees(np.arctan2(test['r'],test['dz']))

train['x1'] = train['dx']/train['dist']
test['x1'] = test['dx']/test['dist']

train['x2'] = train['dx']/train['r']
test['x2'] = test['dx']/test['r']

train['y1'] = train['dy']/train['dist']
test['y1'] = test['dy']/test['dist']

train['y2'] = train['dy']/train['r']
test['y2'] = test['dy']/test['r']

train['sin_theta'] = np.sin(train['theta'])
test['sin_theta'] = np.sin(test['theta'])

train['cos_theta'] = np.cos(train['theta'])
test['cos_theta'] = np.cos(test['theta'])

train['sin_phi'] = np.sin(train['phi'])
test['sin_phi'] = np.sin(test['phi'])

train['cos_phi'] = np.cos(train['phi'])
test['cos_phi'] = np.cos(test['phi'])

train['dxy']  = np.sqrt(train['dx']**2+train['dy']**2)
train['dyz']  = np.sqrt(train['dy']**2+train['dz']**2)
train['dxz']  = np.sqrt(train['dx']**2+train['dz']**2)

test['dxy']  = np.sqrt(test['dx']**2+test['dy']**2)
test['dyz']  = np.sqrt(test['dy']**2+test['dz']**2)
test['dxz']  = np.sqrt(test['dx']**2+test['dz']**2)

# %%
train['type_0'] = train['type'].apply(lambda x: x[0])
test['type_0'] = test['type'].apply(lambda x: x[0])

train['type_1'] = train['type'].apply(lambda x: x[1:])
test['type_1'] = test['type'].apply(lambda x: x[1:])

# %%
train = reduce_mem_usage(train)
test = reduce_mem_usage(test)
# Out:
# Mem. usage decreased to 621.93 Mb (65.0% reduction)
# Mem. usage decreased to 329.75 Mb (64.8% reduction)

# %%
def create_features_full(df):
    df['molecule_couples'] = df.groupby('molecule_name')['id'].transform('count')
    
    df['molecule_dist_mean'] = df.groupby('molecule_name')['dist'].transform('mean')
#     df['molecule_dist_median'] = df.groupby('molecule_name')['dist'].transform('median')
    df['molecule_dist_min'] = df.groupby('molecule_name')['dist'].transform('min')
    df['molecule_dist_max'] = df.groupby('molecule_name')['dist'].transform('max')
    df['molecule_dist_std'] = df.groupby('molecule_name')['dist'].transform('std')
    
    
    
    df['atom_0_couples_count'] = df.groupby(['molecule_name', 'atom_index_0'])['id'].transform('count')
    df['atom_1_couples_count'] = df.groupby(['molecule_name', 'atom_index_1'])['id'].transform('count')
    df['type_0_couples_count'] = df.groupby(['molecule_name', 'type_0'])['id'].transform('count')
    df['type_1_couples_count'] = df.groupby(['molecule_name', 'type_1'])['id'].transform('count')
    
    df['molecule_dxy_mean'] = df.groupby('molecule_name')['dist_x'].transform('mean')
#     df['molecule_dxy_median'] = df.groupby('molecule_name')['dxy'].transform('median')
    df['molecule_dxy_min'] = df.groupby('molecule_name')['dist_x'].transform('min')
    df['molecule_dxy_max'] = df.groupby('molecule_name')['dist_x'].transform('max')
    df['molecule_dxy_std'] = df.groupby('molecule_name')['dist_x'].transform('std')
    
    
    
    df['molecule_dxz_mean'] = df.groupby('molecule_name')['dist_y'].transform('mean')
#     df['molecule_dxz_median'] = df.groupby('molecule_name')['dxz'].transform('median')
    df['molecule_dxz_min'] = df.groupby('molecule_name')['dist_y'].transform('min')
    df['molecule_dxz_max'] = df.groupby('molecule_name')['dist_y'].transform('max')
    df['molecule_dxz_std'] = df.groupby('molecule_name')['dist_y'].transform('std')
   
   
    
    
    df['molecule_dyz_mean'] = df.groupby('molecule_name')['dist_z'].transform('mean')
#     df['molecule_dxy_median'] = df.groupby('molecule_name')['dxy'].transform('median')
    df['molecule_dyz_min'] = df.groupby('molecule_name')['dist_z'].transform('min')
    df['molecule_dyz_max'] = df.groupby('molecule_name')['dist_z'].transform('max')
    df['molecule_dyz_std'] = df.groupby('molecule_name')['dist_z'].transform('std')
    
   
    
    
    num_cols = ['x_1', 'y_1', 'z_1', 'dist', 'dist_x', 'dist_y', 'dist_z']
    cat_cols = ['atom_index_0', 'atom_index_1', 'type', 'atom_1', 'type_0']
    aggs = ['mean', 'max', 'std', 'min']
    for col in cat_cols:
        df[f'molecule_{col}_count'] = df.groupby('molecule_name')[col].transform('count')

    for cat_col in tqdm_notebook(cat_cols):
        for num_col in num_cols:
            for agg in aggs:
                df[f'molecule_{cat_col}_{num_col}_{agg}'] = df.groupby(['molecule_name', cat_col])[num_col].transform(agg)
                df[f'molecule_{cat_col}_{num_col}_{agg}_diff'] = df[f'molecule_{cat_col}_{num_col}_{agg}'] - df[num_col]
                df[f'molecule_{cat_col}_{num_col}_{agg}_div'] = df[f'molecule_{cat_col}_{num_col}_{agg}'] / df[num_col]
#                 df[f'molecule_{cat_col}_{num_col}_{agg}_sum'] = df[f'molecule_{cat_col}_{num_col}_{agg}'] + df[num_col]
#                 df[f'molecule_{cat_col}_{num_col}_{agg}_mult'] = df[f'molecule_{cat_col}_{num_col}_{agg}'] * df[num_col]


    df = reduce_mem_usage(df)
    return df

# %%
train = create_features_full(train)
# Out:
# HBox(children=(IntProgress(value=0, max=5), HTML(value='')))

# %%
test = create_features_full(test)

# %%
# train.to_csv('../cache/train2.csv', index=False)
# test.to_csv('../cache/test2.csv', index=False)

# %%
# train = pd.read_csv('../cache/train2.csv')
# test = pd.read_csv('../cache/test2.csv')

# %%
for f in ['atom_index_0', 'atom_index_1', 'atom_1', 'type_0', 'type', 'atom_0', 'type_1']:
#     if f in good_columns:
    lbl = LabelEncoder()
    lbl.fit(list(train[f].values) + list(test[f].values))
    train[f] = lbl.transform(list(train[f].values))
    test[f] = lbl.transform(list(test[f].values))

# %%
# train = reduce_mem_usage(train)
# test = reduce_mem_usage(test)

# %%
good_columns = [
'molecule_atom_index_0_dist_min',
'molecule_atom_index_0_dist_max',
'molecule_atom_index_1_dist_min',
'molecule_atom_index_0_dist_mean',
'molecule_atom_index_0_dist_std',
'dist',
'molecule_atom_index_1_dist_std',
'molecule_atom_index_1_dist_max',
'molecule_atom_index_1_dist_mean',
'molecule_atom_index_0_dist_max_diff',
'molecule_atom_index_0_dist_max_div',
'molecule_atom_index_0_dist_std_diff',
'molecule_atom_index_0_dist_std_div',
'atom_0_couples_count',
'molecule_atom_index_0_dist_min_div',
'molecule_atom_index_1_dist_std_diff',
'molecule_atom_index_0_dist_mean_div',
'atom_1_couples_count',
'molecule_atom_index_0_dist_mean_diff',
'molecule_couples',
'atom_index_1',
'molecule_dist_mean',
'molecule_atom_index_1_dist_max_diff',
'molecule_atom_index_0_y_1_std',
'molecule_atom_index_1_dist_mean_diff',
'molecule_atom_index_1_dist_std_div',
'molecule_atom_index_1_dist_mean_div',
'molecule_atom_index_1_dist_min_diff',
'molecule_atom_index_1_dist_min_div',
'molecule_atom_index_1_dist_max_div',
'molecule_atom_index_0_z_1_std',
'y_0',
'molecule_type_dist_std_diff',
'molecule_atom_1_dist_min_diff',
'molecule_atom_index_0_x_1_std',
'molecule_dist_min',
'molecule_atom_index_0_dist_min_diff',
'molecule_atom_index_0_y_1_mean_diff',
'molecule_type_dist_min',
'molecule_atom_1_dist_min_div',
'atom_index_0',
'molecule_dist_max',
'molecule_atom_1_dist_std_diff',
'molecule_type_dist_max',
'molecule_atom_index_0_y_1_max_diff',
'molecule_type_0_dist_std_diff',
'molecule_type_dist_mean_diff',
'molecule_atom_1_dist_mean',
'molecule_atom_index_0_y_1_mean_div',
'molecule_type_dist_mean_div',
'type',
'EN_x', 'rad_x',
'n_bonds_x', 'bond_lengths_mean_x','EN_y', 'rad_y', 'n_bonds_y', 'bond_lengths_mean_y'
]

# %%
good_columns = [
'molecule_atom_index_0_dist_min',
'molecule_atom_index_0_dist_max',
'molecule_atom_index_1_dist_min',
'molecule_atom_index_0_dist_mean',
'molecule_atom_index_0_dist_std',
'dist',
'molecule_atom_index_1_dist_std',
'molecule_atom_index_1_dist_max',
'molecule_atom_index_1_dist_mean',
'molecule_atom_index_0_dist_max_diff',
'molecule_atom_index_0_dist_max_div',
'molecule_atom_index_0_dist_std_diff',
'molecule_atom_index_0_dist_std_div',
'atom_0_couples_count',
'molecule_atom_index_0_dist_min_div',
'molecule_atom_index_1_dist_std_diff',
'molecule_atom_index_0_dist_mean_div',
'atom_1_couples_count',
'molecule_atom_index_0_dist_mean_diff',
'molecule_couples',
'atom_index_1',
'molecule_dist_mean',
'molecule_atom_index_1_dist_max_diff',
'molecule_atom_index_0_y_1_std',
'molecule_atom_index_1_dist_mean_diff',
'molecule_atom_index_1_dist_std_div',
'molecule_atom_index_1_dist_mean_div',
'molecule_atom_index_1_dist_min_diff',
'molecule_atom_index_1_dist_min_div',
'molecule_atom_index_1_dist_max_div',
'molecule_atom_index_0_z_1_std',
'y_0',
'molecule_type_dist_std_diff',
'molecule_atom_1_dist_min_diff',
'molecule_atom_index_0_x_1_std',
'molecule_dist_min',
'molecule_atom_index_0_dist_min_diff',
'molecule_atom_index_0_y_1_mean_diff',
'molecule_type_dist_min',
'molecule_atom_1_dist_min_div',
'atom_index_0',
'molecule_dist_max',
'molecule_atom_1_dist_std_diff',
'molecule_type_dist_max',
'molecule_atom_index_0_y_1_max_diff',
'molecule_type_0_dist_std_diff',
'molecule_type_dist_mean_diff',
'molecule_atom_1_dist_mean',
'molecule_atom_index_0_y_1_mean_div',
'molecule_type_dist_mean_div',
'type',
'dx',
'dy',
'dz',
'r',
'dxz',
'dyz',
# 'phi',
# 'phi_deg',
# 'z1',
# 'z2',
# 'theta',
# 'theta_deg',
# 'x1',
# 'x2',
# 'y1',
# 'y2',
# 'z1',
# 'z2',
'sin_theta',
'cos_theta',
'sin_phi',
'cos_phi',
# 'molecule_dxy_mean',
# 'molecule_dxy_min',
# 'molecule_dxy_max',

# 'molecule_dxz_mean',
# 'molecule_dxz_min',
# 'molecule_dxz_max',

# 'molecule_dyz_mean',
# 'molecule_dyz_min',
# 'molecule_dyz_max',

# 'molecule_atom_index_0_dist_x_min',
# 'molecule_atom_index_0_dist_x_max',
# 'molecule_atom_index_0_dist_x_mean',
# 'molecule_atom_index_0_dist_x_std',

# 'molecule_atom_index_0_dist_y_min',
# 'molecule_atom_index_0_dist_y_max',
# 'molecule_atom_index_0_dist_y_mean',
# 'molecule_atom_index_0_dist_y_std',
    
# 'molecule_atom_index_0_dist_z_min',
# 'molecule_atom_index_0_dist_z_max',
# 'molecule_atom_index_0_dist_z_mean',
# 'molecule_atom_index_0_dist_z_std',
    
# 'molecule_atom_index_1_dist_x_min',
# 'molecule_atom_index_1_dist_x_max',
# 'molecule_atom_index_1_dist_x_mean',
# 'molecule_atom_index_1_dist_x_std',

# 'molecule_atom_index_1_dist_y_min',
# 'molecule_atom_index_1_dist_y_max',
# 'molecule_atom_index_1_dist_y_mean',
# 'molecule_atom_index_1_dist_y_std',
    
# 'molecule_atom_index_1_dist_z_min',
# 'molecule_atom_index_1_dist_z_max',
# 'molecule_atom_index_1_dist_z_mean',
# 'molecule_atom_index_1_dist_z_std',
    
# 'molecule_type_dist_x_min',
# 'molecule_type_dist_x_max',
# 'molecule_type_dist_x_mean',
# 'molecule_type_dist_x_std',

# 'molecule_type_dist_y_min',
# 'molecule_type_dist_y_max',
# 'molecule_type_dist_y_mean',
# 'molecule_type_dist_y_std',
    
# 'molecule_type_dist_z_min',
# 'molecule_type_dist_z_max',
# 'molecule_type_dist_z_mean',
# 'molecule_type_dist_z_std',
    
# 'molecule_atom_1_dist_x_min',
# 'molecule_atom_1_dist_x_max',
# 'molecule_atom_1_dist_x_mean',
# 'molecule_atom_1_dist_x_std',

# 'molecule_atom_1_dist_y_min',
# 'molecule_atom_1_dist_y_max',
# 'molecule_atom_1_dist_y_mean',
# 'molecule_atom_1_dist_y_std',
    
# 'molecule_atom_1_dist_z_min',
# 'molecule_atom_1_dist_z_max',
# 'molecule_atom_1_dist_z_mean',
# 'molecule_atom_1_dist_z_std',
]

# %%
good_columns = [
    'molecule_atom_index_0_dist_min',
    'molecule_atom_index_0_dist_max',
    'molecule_atom_index_0_dist_mean',
    'molecule_atom_index_0_dist_std',
    'y_0',
    'molecule_atom_index_0_y_1_std',
    'molecule_atom_index_1_dist_min',
    'molecule_atom_index_0_y_1_mean_div',
    'molecule_atom_index_0_z_1_std',
    'molecule_dist_mean',
    'molecule_atom_index_1_dist_std',
    'molecule_atom_index_0_x_1_std',
    'molecule_atom_index_1_dist_max',
    'molecule_atom_index_0_y_1_mean_diff',
    'molecule_atom_index_0_dist_mean',
    
    'molecule_dist_max',
    'molecule_atom_1_dist_mean',
    'molecule_atom_index_0_y_1_max_diff',
    'molecule_couples',
    'molecule_atom_1_dist_std_diff',
    'molecule_type_dist_max',
    'molecule_dist_min',
    'molecule_type_dist_min',
    'molecule_atom_index_0_dist_std_div',
    'molecule_atom_index_1_dist_std_diff',
    'molecule_atom_index_0_dist_mean_div',
    'molecule_atom_index_1_dist_std_diff',
    'atom_index_1',
    'molecule_atom_index_0_dist_max_div',
    'molecule_atom_index_0_dist_max_diff',
    'molecule_type_0_dist_std_diff',
    'molecule_atom_index_0_dist_mean_diff',
    'molecule_atom_index_1_dist_std_diff',
    'molecule_type_dist_mean_diff',
]

# %%
good_columns = [
    'molecule_atom_index_0_dist_min',
    'molecule_atom_index_0_dist_max',
    'molecule_atom_index_1_dist_min',
    'molecule_atom_index_0_dist_mean',
    'molecule_atom_index_0_dist_std',
    'dist',
    'molecule_atom_index_1_dist_std',
    'molecule_atom_index_1_dist_max',
    'molecule_atom_index_1_dist_mean',
    'molecule_atom_index_0_dist_max_diff',
    'molecule_atom_index_0_dist_max_div',
    'molecule_atom_index_0_dist_std_diff',
    'molecule_atom_index_0_dist_std_div',
    'atom_0_couples_count',
    'molecule_atom_index_0_dist_min_div',
    'molecule_atom_index_1_dist_std_diff',
    'molecule_atom_index_0_dist_mean_div',
    'atom_1_couples_count',
    'molecule_atom_index_0_dist_mean_diff',
    'molecule_couples',
    'atom_index_1',
    'molecule_dist_mean',
    'molecule_atom_index_1_dist_max_diff',
    'molecule_atom_index_0_y_1_std',
    'molecule_atom_index_1_dist_mean_diff',
]

# %%
list(train.columns)
# Out:
# ['id',
#  'molecule_name',
#  'atom_index_0',
#  'atom_index_1',
#  'type',
#  'scalar_coupling_constant',
#  'atom_0',
#  'x_0',
#  'y_0',
#  'z_0',
#  'atom_1',
#  'x_1',
#  'y_1',
#  'z_1',
#  'dist',
#  'dist_x',
#  'dist_y',
#  'dist_z',
#  'dx',
#  'dy',
#  'dz',
#  'r',
#  'phi',
#  'phi_deg',
#  'z1',
#  'z2',
#  'theta',
#  'theta_deg',
#  'x1',
#  'x2',
#  'y1',
#  'y2',
#  'sin_theta',
#  'cos_theta',
#  'sin_phi',
#  'cos_phi',
#  'dxy',
#  'dyz',
#  'dxz',
#  'type_0',
#  'type_1',
#  'molecule_couples',
#  'molecule_dist_mean',
#  'molecule_dist_min',
#  'molecule_dist_max',
#  'molecule_dist_std',
#  'atom_0_couples_count',
#  'atom_1_couples_count',
#  'type_0_couples_count',
#  'type_1_couples_count',
#  'molecule_dxy_mean',
#  'molecule_dxy_min',
#  'molecule_dxy_max',
#  'molecule_dxy_std',
#  'molecule_dxz_mean',
#  'molecule_dxz_min',
#  'molecule_dxz_max',
#  'molecule_dxz_std',
#  'molecule_dyz_mean',
#  'molecule_dyz_min',
#  'molecule_dyz_max',
#  'molecule_dyz_std',
#  'molecule_atom_index_0_count',
#  'molecule_atom_index_1_count',
#  'molecule_type_count',
#  'molecule_atom_1_count',
#  'molecule_type_0_count',
#  'molecule_atom_index_0_x_1_mean',
#  'molecule_atom_index_0_x_1_mean_diff',
#  'molecule_atom_index_0_x_1_mean_div',
#  'molecule_atom_index_0_x_1_max',
#  'molecule_atom_index_0_x_1_max_diff',
#  'molecule_atom_index_0_x_1_max_div',
#  'molecule_atom_index_0_x_1_std',
#  'molecule_atom_index_0_x_1_std_diff',
#  'molecule_atom_index_0_x_1_std_div',
#  'molecule_atom_index_0_x_1_min',
#  'molecule_atom_index_0_x_1_min_diff',
#  'molecule_atom_index_0_x_1_min_div',
#  'molecule_atom_index_0_y_1_mean',
#  'molecule_atom_index_0_y_1_mean_diff',
#  'molecule_atom_index_0_y_1_mean_div',
#  'molecule_atom_index_0_y_1_max',
#  'molecule_atom_index_0_y_1_max_diff',
#  'molecule_atom_index_0_y_1_max_div',
#  'molecule_atom_index_0_y_1_std',
#  'molecule_atom_index_0_y_1_std_diff',
#  'molecule_atom_index_0_y_1_std_div',
#  'molecule_atom_index_0_y_1_min',
#  'molecule_atom_index_0_y_1_min_diff',
#  'molecule_atom_index_0_y_1_min_div',
#  'molecule_atom_index_0_z_1_mean',
#  'molecule_atom_index_0_z_1_mean_diff',
#  'molecule_atom_index_0_z_1_mean_div',
#  'molecule_atom_index_0_z_1_max',
#  'molecule_atom_index_0_z_1_max_diff',
#  'molecule_atom_index_0_z_1_max_div',
#  'molecule_atom_index_0_z_1_std',
#  'molecule_atom_index_0_z_1_std_diff',
#  'molecule_atom_index_0_z_1_std_div',
#  'molecule_atom_index_0_z_1_min',
#  'molecule_atom_index_0_z_1_min_diff',
#  'molecule_atom_index_0_z_1_min_div',
#  'molecule_atom_index_0_dist_mean',
#  'molecule_atom_index_0_dist_mean_diff',
#  'molecule_atom_index_0_dist_mean_div',
#  'molecule_atom_index_0_dist_max',
#  'molecule_atom_index_0_dist_max_diff',
#  'molecule_atom_index_0_dist_max_div',
#  'molecule_atom_index_0_dist_std',
#  'molecule_atom_index_0_dist_std_diff',
#  'molecule_atom_index_0_dist_std_div',
#  'molecule_atom_index_0_dist_min',
#  'molecule_atom_index_0_dist_min_diff',
#  'molecule_atom_index_0_dist_min_div',
#  'molecule_atom_index_0_dist_x_mean',
#  'molecule_atom_index_0_dist_x_mean_diff',
#  'molecule_atom_index_0_dist_x_mean_div',
#  'molecule_atom_index_0_dist_x_max',
#  'molecule_atom_index_0_dist_x_max_diff',
#  'molecule_atom_index_0_dist_x_max_div',
#  'molecule_atom_index_0_dist_x_std',
#  'molecule_atom_index_0_dist_x_std_diff',
#  'molecule_atom_index_0_dist_x_std_div',
#  'molecule_atom_index_0_dist_x_min',
#  'molecule_atom_index_0_dist_x_min_diff',
#  'molecule_atom_index_0_dist_x_min_div',
#  'molecule_atom_index_0_dist_y_mean',
#  'molecule_atom_index_0_dist_y_mean_diff',
#  'molecule_atom_index_0_dist_y_mean_div',
#  'molecule_atom_index_0_dist_y_max',
#  'molecule_atom_index_0_dist_y_max_diff',
#  'molecule_atom_index_0_dist_y_max_div',
#  'molecule_atom_index_0_dist_y_std',
#  'molecule_atom_index_0_dist_y_std_diff',
#  'molecule_atom_index_0_dist_y_std_div',
#  'molecule_atom_index_0_dist_y_min',
#  'molecule_atom_index_0_dist_y_min_diff',
#  'molecule_atom_index_0_dist_y_min_div',
#  'molecule_atom_index_0_dist_z_mean',
#  'molecule_atom_index_0_dist_z_mean_diff',
#  'molecule_atom_index_0_dist_z_mean_div',
#  'molecule_atom_index_0_dist_z_max',
#  'molecule_atom_index_0_dist_z_max_diff',
#  'molecule_atom_index_0_dist_z_max_div',
#  'molecule_atom_index_0_dist_z_std',
#  'molecule_atom_index_0_dist_z_std_diff',
#  'molecule_atom_index_0_dist_z_std_div',
#  'molecule_atom_index_0_dist_z_min',
#  'molecule_atom_index_0_dist_z_min_diff',
#  'molecule_atom_index_0_dist_z_min_div',
#  'molecule_atom_index_1_x_1_mean',
#  'molecule_atom_index_1_x_1_mean_diff',
#  'molecule_atom_index_1_x_1_mean_div',
#  'molecule_atom_index_1_x_1_max',
#  'molecule_atom_index_1_x_1_max_diff',
#  'molecule_atom_index_1_x_1_max_div',
#  'molecule_atom_index_1_x_1_std',
#  'molecule_atom_index_1_x_1_std_diff',
#  'molecule_atom_index_1_x_1_std_div',
#  'molecule_atom_index_1_x_1_min',
#  'molecule_atom_index_1_x_1_min_diff',
#  'molecule_atom_index_1_x_1_min_div',
#  'molecule_atom_index_1_y_1_mean',
#  'molecule_atom_index_1_y_1_mean_diff',
#  'molecule_atom_index_1_y_1_mean_div',
#  'molecule_atom_index_1_y_1_max',
#  'molecule_atom_index_1_y_1_max_diff',
#  'molecule_atom_index_1_y_1_max_div',
#  'molecule_atom_index_1_y_1_std',
#  'molecule_atom_index_1_y_1_std_diff',
#  'molecule_atom_index_1_y_1_std_div',
#  'molecule_atom_index_1_y_1_min',
#  'molecule_atom_index_1_y_1_min_diff',
#  'molecule_atom_index_1_y_1_min_div',
#  'molecule_atom_index_1_z_1_mean',
#  'molecule_atom_index_1_z_1_mean_diff',
#  'molecule_atom_index_1_z_1_mean_div',
#  'molecule_atom_index_1_z_1_max',
#  'molecule_atom_index_1_z_1_max_diff',
#  'molecule_atom_index_1_z_1_max_div',
#  'molecule_atom_index_1_z_1_std',
#  'molecule_atom_index_1_z_1_std_diff',
#  'molecule_atom_index_1_z_1_std_div',
#  'molecule_atom_index_1_z_1_min',
#  'molecule_atom_index_1_z_1_min_diff',
#  'molecule_atom_index_1_z_1_min_div',
#  'molecule_atom_index_1_dist_mean',
#  'molecule_atom_index_1_dist_mean_diff',
#  'molecule_atom_index_1_dist_mean_div',
#  'molecule_atom_index_1_dist_max',
#  'molecule_atom_index_1_dist_max_diff',
#  'molecule_atom_index_1_dist_max_div',
#  'molecule_atom_index_1_dist_std',
#  'molecule_atom_index_1_dist_std_diff',
#  'molecule_atom_index_1_dist_std_div',
#  'molecule_atom_index_1_dist_min',
#  'molecule_atom_index_1_dist_min_diff',
#  'molecule_atom_index_1_dist_min_div',
#  'molecule_atom_index_1_dist_x_mean',
#  'molecule_atom_index_1_dist_x_mean_diff',
#  'molecule_atom_index_1_dist_x_mean_div',
#  'molecule_atom_index_1_dist_x_max',
#  'molecule_atom_index_1_dist_x_max_diff',
#  'molecule_atom_index_1_dist_x_max_div',
#  'molecule_atom_index_1_dist_x_std',
#  'molecule_atom_index_1_dist_x_std_diff',
#  'molecule_atom_index_1_dist_x_std_div',
#  'molecule_atom_index_1_dist_x_min',
#  'molecule_atom_index_1_dist_x_min_diff',
#  'molecule_atom_index_1_dist_x_min_div',
#  'molecule_atom_index_1_dist_y_mean',
#  'molecule_atom_index_1_dist_y_mean_diff',
#  'molecule_atom_index_1_dist_y_mean_div',
#  'molecule_atom_index_1_dist_y_max',
#  'molecule_atom_index_1_dist_y_max_diff',
#  'molecule_atom_index_1_dist_y_max_div',
#  'molecule_atom_index_1_dist_y_std',
#  'molecule_atom_index_1_dist_y_std_diff',
#  'molecule_atom_index_1_dist_y_std_div',
#  'molecule_atom_index_1_dist_y_min',
#  'molecule_atom_index_1_dist_y_min_diff',
#  'molecule_atom_index_1_dist_y_min_div',
#  'molecule_atom_index_1_dist_z_mean',
#  'molecule_atom_index_1_dist_z_mean_diff',
#  'molecule_atom_index_1_dist_z_mean_div',
#  'molecule_atom_index_1_dist_z_max',
#  'molecule_atom_index_1_dist_z_max_diff',
#  'molecule_atom_index_1_dist_z_max_div',
#  'molecule_atom_index_1_dist_z_std',
#  'molecule_atom_index_1_dist_z_std_diff',
#  'molecule_atom_index_1_dist_z_std_div',
#  'molecule_atom_index_1_dist_z_min',
#  'molecule_atom_index_1_dist_z_min_diff',
#  'molecule_atom_index_1_dist_z_min_div',
#  'molecule_type_x_1_mean',
#  'molecule_type_x_1_mean_diff',
#  'molecule_type_x_1_mean_div',
#  'molecule_type_x_1_max',
#  'molecule_type_x_1_max_diff',
#  'molecule_type_x_1_max_div',
#  'molecule_type_x_1_std',
#  'molecule_type_x_1_std_diff',
#  'molecule_type_x_1_std_div',
#  'molecule_type_x_1_min',
#  'molecule_type_x_1_min_diff',
#  'molecule_type_x_1_min_div',
#  'molecule_type_y_1_mean',
#  'molecule_type_y_1_mean_diff',
#  'molecule_type_y_1_mean_div',
#  'molecule_type_y_1_max',
#  'molecule_type_y_1_max_diff',
#  'molecule_type_y_1_max_div',
#  'molecule_type_y_1_std',
#  'molecule_type_y_1_std_diff',
#  'molecule_type_y_1_std_div',
#  'molecule_type_y_1_min',
#  'molecule_type_y_1_min_diff',
#  'molecule_type_y_1_min_div',
#  'molecule_type_z_1_mean',
#  'molecule_type_z_1_mean_diff',
#  'molecule_type_z_1_mean_div',
#  'molecule_type_z_1_max',
#  'molecule_type_z_1_max_diff',
#  'molecule_type_z_1_max_div',
#  'molecule_type_z_1_std',
#  'molecule_type_z_1_std_diff',
#  'molecule_type_z_1_std_div',
#  'molecule_type_z_1_min',
#  'molecule_type_z_1_min_diff',
#  'molecule_type_z_1_min_div',
#  'molecule_type_dist_mean',
#  'molecule_type_dist_mean_diff',
#  'molecule_type_dist_mean_div',
#  'molecule_type_dist_max',
#  'molecule_type_dist_max_diff',
#  'molecule_type_dist_max_div',
#  'molecule_type_dist_std',
#  'molecule_type_dist_std_diff',
#  'molecule_type_dist_std_div',
#  'molecule_type_dist_min',
#  'molecule_type_dist_min_diff',
#  'molecule_type_dist_min_div',
#  'molecule_type_dist_x_mean',
#  'molecule_type_dist_x_mean_diff',
#  'molecule_type_dist_x_mean_div',
#  'molecule_type_dist_x_max',
#  'molecule_type_dist_x_max_diff',
#  'molecule_type_dist_x_max_div',
#  'molecule_type_dist_x_std',
#  'molecule_type_dist_x_std_diff',
#  'molecule_type_dist_x_std_div',
#  'molecule_type_dist_x_min',
#  'molecule_type_dist_x_min_diff',
#  'molecule_type_dist_x_min_div',
#  'molecule_type_dist_y_mean',
#  'molecule_type_dist_y_mean_diff',
#  'molecule_type_dist_y_mean_div',
#  'molecule_type_dist_y_max',
#  'molecule_type_dist_y_max_diff',
#  'molecule_type_dist_y_max_div',
#  'molecule_type_dist_y_std',
#  'molecule_type_dist_y_std_diff',
#  'molecule_type_dist_y_std_div',
#  'molecule_type_dist_y_min',
#  'molecule_type_dist_y_min_diff',
#  'molecule_type_dist_y_min_div',
#  'molecule_type_dist_z_mean',
#  'molecule_type_dist_z_mean_diff',
#  'molecule_type_dist_z_mean_div',
#  'molecule_type_dist_z_max',
#  'molecule_type_dist_z_max_diff',
#  'molecule_type_dist_z_max_div',
#  'molecule_type_dist_z_std',
#  'molecule_type_dist_z_std_diff',
#  'molecule_type_dist_z_std_div',
#  'molecule_type_dist_z_min',
#  'molecule_type_dist_z_min_diff',
#  'molecule_type_dist_z_min_div',
#  'molecule_atom_1_x_1_mean',
#  'molecule_atom_1_x_1_mean_diff',
#  'molecule_atom_1_x_1_mean_div',
#  'molecule_atom_1_x_1_max',
#  'molecule_atom_1_x_1_max_diff',
#  'molecule_atom_1_x_1_max_div',
#  'molecule_atom_1_x_1_std',
#  'molecule_atom_1_x_1_std_diff',
#  'molecule_atom_1_x_1_std_div',
#  'molecule_atom_1_x_1_min',
#  'molecule_atom_1_x_1_min_diff',
#  'molecule_atom_1_x_1_min_div',
#  'molecule_atom_1_y_1_mean',
#  'molecule_atom_1_y_1_mean_diff',
#  'molecule_atom_1_y_1_mean_div',
#  'molecule_atom_1_y_1_max',
#  'molecule_atom_1_y_1_max_diff',
#  'molecule_atom_1_y_1_max_div',
#  'molecule_atom_1_y_1_std',
#  'molecule_atom_1_y_1_std_diff',
#  'molecule_atom_1_y_1_std_div',
#  'molecule_atom_1_y_1_min',
#  'molecule_atom_1_y_1_min_diff',
#  'molecule_atom_1_y_1_min_div',
#  'molecule_atom_1_z_1_mean',
#  'molecule_atom_1_z_1_mean_diff',
#  'molecule_atom_1_z_1_mean_div',
#  'molecule_atom_1_z_1_max',
#  'molecule_atom_1_z_1_max_diff',
#  'molecule_atom_1_z_1_max_div',
#  'molecule_atom_1_z_1_std',
#  'molecule_atom_1_z_1_std_diff',
#  'molecule_atom_1_z_1_std_div',
#  'molecule_atom_1_z_1_min',
#  'molecule_atom_1_z_1_min_diff',
#  'molecule_atom_1_z_1_min_div',
#  'molecule_atom_1_dist_mean',
#  'molecule_atom_1_dist_mean_diff',
#  'molecule_atom_1_dist_mean_div',
#  'molecule_atom_1_dist_max',
#  'molecule_atom_1_dist_max_diff',
#  'molecule_atom_1_dist_max_div',
#  'molecule_atom_1_dist_std',
#  'molecule_atom_1_dist_std_diff',
#  'molecule_atom_1_dist_std_div',
#  'molecule_atom_1_dist_min',
#  'molecule_atom_1_dist_min_diff',
#  'molecule_atom_1_dist_min_div',
#  'molecule_atom_1_dist_x_mean',
#  'molecule_atom_1_dist_x_mean_diff',
#  'molecule_atom_1_dist_x_mean_div',
#  'molecule_atom_1_dist_x_max',
#  'molecule_atom_1_dist_x_max_diff',
#  'molecule_atom_1_dist_x_max_div',
#  'molecule_atom_1_dist_x_std',
#  'molecule_atom_1_dist_x_std_diff',
#  'molecule_atom_1_dist_x_std_div',
#  'molecule_atom_1_dist_x_min',
#  'molecule_atom_1_dist_x_min_diff',
#  'molecule_atom_1_dist_x_min_div',
#  'molecule_atom_1_dist_y_mean',
#  'molecule_atom_1_dist_y_mean_diff',
#  'molecule_atom_1_dist_y_mean_div',
#  'molecule_atom_1_dist_y_max',
#  'molecule_atom_1_dist_y_max_diff',
#  'molecule_atom_1_dist_y_max_div',
#  'molecule_atom_1_dist_y_std',
#  'molecule_atom_1_dist_y_std_diff',
#  'molecule_atom_1_dist_y_std_div',
#  'molecule_atom_1_dist_y_min',
#  'molecule_atom_1_dist_y_min_diff',
#  'molecule_atom_1_dist_y_min_div',
#  'molecule_atom_1_dist_z_mean',
#  'molecule_atom_1_dist_z_mean_diff',
#  'molecule_atom_1_dist_z_mean_div',
#  'molecule_atom_1_dist_z_max',
#  'molecule_atom_1_dist_z_max_diff',
#  'molecule_atom_1_dist_z_max_div',
#  'molecule_atom_1_dist_z_std',
#  'molecule_atom_1_dist_z_std_diff',
#  'molecule_atom_1_dist_z_std_div',
#  'molecule_atom_1_dist_z_min',
#  'molecule_atom_1_dist_z_min_diff',
#  'molecule_atom_1_dist_z_min_div',
#  'molecule_type_0_x_1_mean',
#  'molecule_type_0_x_1_mean_diff',
#  'molecule_type_0_x_1_mean_div',
#  'molecule_type_0_x_1_max',
#  'molecule_type_0_x_1_max_diff',
#  'molecule_type_0_x_1_max_div',
#  'molecule_type_0_x_1_std',
#  'molecule_type_0_x_1_std_diff',
#  'molecule_type_0_x_1_std_div',
#  'molecule_type_0_x_1_min',
#  'molecule_type_0_x_1_min_diff',
#  'molecule_type_0_x_1_min_div',
#  'molecule_type_0_y_1_mean',
#  'molecule_type_0_y_1_mean_diff',
#  'molecule_type_0_y_1_mean_div',
#  'molecule_type_0_y_1_max',
#  'molecule_type_0_y_1_max_diff',
#  'molecule_type_0_y_1_max_div',
#  'molecule_type_0_y_1_std',
#  'molecule_type_0_y_1_std_diff',
#  'molecule_type_0_y_1_std_div',
#  'molecule_type_0_y_1_min',
#  'molecule_type_0_y_1_min_diff',
#  'molecule_type_0_y_1_min_div',
#  'molecule_type_0_z_1_mean',
#  'molecule_type_0_z_1_mean_diff',
#  'molecule_type_0_z_1_mean_div',
#  'molecule_type_0_z_1_max',
#  'molecule_type_0_z_1_max_diff',
#  'molecule_type_0_z_1_max_div',
#  'molecule_type_0_z_1_std',
#  'molecule_type_0_z_1_std_diff',
#  'molecule_type_0_z_1_std_div',
#  'molecule_type_0_z_1_min',
#  'molecule_type_0_z_1_min_diff',
#  'molecule_type_0_z_1_min_div',
#  'molecule_type_0_dist_mean',
#  'molecule_type_0_dist_mean_diff',
#  'molecule_type_0_dist_mean_div',
#  'molecule_type_0_dist_max',
#  'molecule_type_0_dist_max_diff',
#  'molecule_type_0_dist_max_div',
#  'molecule_type_0_dist_std',
#  'molecule_type_0_dist_std_diff',
#  'molecule_type_0_dist_std_div',
#  'molecule_type_0_dist_min',
#  'molecule_type_0_dist_min_diff',
#  'molecule_type_0_dist_min_div',
#  'molecule_type_0_dist_x_mean',
#  'molecule_type_0_dist_x_mean_diff',
#  'molecule_type_0_dist_x_mean_div',
#  'molecule_type_0_dist_x_max',
#  'molecule_type_0_dist_x_max_diff',
#  'molecule_type_0_dist_x_max_div',
#  'molecule_type_0_dist_x_std',
#  'molecule_type_0_dist_x_std_diff',
#  'molecule_type_0_dist_x_std_div',
#  'molecule_type_0_dist_x_min',
#  'molecule_type_0_dist_x_min_diff',
#  'molecule_type_0_dist_x_min_div',
#  'molecule_type_0_dist_y_mean',
#  'molecule_type_0_dist_y_mean_diff',
#  'molecule_type_0_dist_y_mean_div',
#  'molecule_type_0_dist_y_max',
#  'molecule_type_0_dist_y_max_diff',
#  'molecule_type_0_dist_y_max_div',
#  'molecule_type_0_dist_y_std',
#  'molecule_type_0_dist_y_std_diff',
#  'molecule_type_0_dist_y_std_div',
#  'molecule_type_0_dist_y_min',
#  'molecule_type_0_dist_y_min_diff',
#  'molecule_type_0_dist_y_min_div',
#  'molecule_type_0_dist_z_mean',
#  'molecule_type_0_dist_z_mean_diff',
#  'molecule_type_0_dist_z_mean_div',
#  'molecule_type_0_dist_z_max',
#  'molecule_type_0_dist_z_max_diff',
#  'molecule_type_0_dist_z_max_div',
#  'molecule_type_0_dist_z_std',
#  'molecule_type_0_dist_z_std_diff',
#  'molecule_type_0_dist_z_std_div',
#  'molecule_type_0_dist_z_min',
#  'molecule_type_0_dist_z_min_diff',
#  'molecule_type_0_dist_z_min_div']

# %%
train.shape
# Out:
# (4658147, 487)

# %%
good_columns = [
    'molecule_atom_index_0_dist_min',
    'molecule_atom_index_0_dist_max', # 24.42
    'atom_index_0', #24.3873
    'atom_index_1', #16.8178
    'type', #2.18402
#     'atom_0' #2.18402
    'x_0', #2.15712
    'y_0', #2.10615
    'z_0', #2.08603
    'atom_1', #2.08291
    'x_1', #1.99933
    'y_1', #1.95652
    'z_1', #1.89673
    'dist', #1.59632
#     'dist_x', #1.59741
    'dist_y', #1.59478
#     'dist_z', #1.59505
#     'dx', #1.59686
#     'dy', #1.59676
#     'dz', #1.59694
    'r', #1.59287
#     'phi' #1.59777
#     'phi_deg', #1.59672
#     'z1', #1.5956
#     'z2', #1.5991
#     'theta', # 1.59975
#     'theta_deg' #1.59734
#     'x1', #1.59675
#     'x2', #1.59679
#     'y1', #1.59991
#     'y2', #1.5986
#     'sin_theta', #1.59712
#     'cos_theta', #1.5956
#     'sin_phi', #1.5986
#     'cos_phi' #1.59679
#     'dyz', #1.59809
#     'dxz', #1.59695
#     'type_0', #1.59287
#     'type_1', # 1.59287
    'molecule_couples', #1.55716
    'molecule_dist_mean', #1.53695
    'molecule_dist_min', #1.52542
    'molecule_dist_max', #1.51814,
    'molecule_dist_std', #1.51487
    'atom_0_couples_count', #1.46383
    'atom_1_couples_count', #1.43409
#     'type_0_couples_count', #1.4352
    'type_1_couples_count', #1.43095
#     'molecule_dxy_mean', #1.43301
#     'molecule_dxy_min', #1.43352
#     'molecule_dxy_max', # 1.4334
#     'molecule_dxy_std', #1.43231
    'molecule_dyz_mean', #1.43037
#     'molecule_dyz_min', #1.43093
#     'molecule_dyz_max', #1.43452
#     'molecule_dyz_std', #1.43188
    'molecule_dxz_mean', #1.43007
#     'molecule_dxz_min', #1.43067
#     'molecule_dxz_max', #1.43559
#     'molecule_dxz_std', #1.43229
#     'molecule_atom_index_0_count', #1.43007
#     'molecule_atom_index_1_count', #1.43007
#     'molecule_type_count', #1.43007
#     'molecule_atom_1_count', #1.43007
#     'molecule_type_0_count', #1.43007
    'molecule_atom_index_0_x_1_mean', #1.42564
    'molecule_atom_index_0_x_1_mean_diff', #1.42405
#     'molecule_atom_index_0_x_1_mean_div', #1.42634
#     'molecule_atom_index_0_x_1_max', #1.4263
    'molecule_atom_index_0_x_1_max_diff', #1.4161
#     'molecule_atom_index_0_x_1_max_div', #1.4226
#     'molecule_atom_index_0_x_1_std', # 1.42286
#     'molecule_atom_index_0_x_1_std_diff', #1.4253
#     'molecule_atom_index_0_x_1_std_div', #1.42493
#     'molecule_atom_index_0_x_1_min', #1.42229
#     'molecule_atom_index_0_x_1_min_diff', #1.42594
#     'molecule_atom_index_0_x_1_min_div', #1.42024
    'molecule_atom_index_0_y_1_mean', #1.41604
    'molecule_atom_index_0_y_1_mean_diff', #1.41118
#     'molecule_atom_index_0_y_1_mean_div', #1.41211
    'molecule_atom_index_0_y_1_max', #1.40826
    'molecule_atom_index_0_y_1_max_diff', #1.40184
#     'molecule_atom_index_0_y_1_max_div', #1.406
    'molecule_atom_index_0_y_1_std', # 1.40109
    'molecule_atom_index_0_y_1_std_diff', #1.39787
#     'molecule_atom_index_0_y_1_std_div', #1.401
#     'molecule_atom_index_0_y_1_min', #1.39971
    'molecule_atom_index_0_y_1_min_diff', #1.39624
#     'molecule_atom_index_0_y_1_min_div', #1.39703
    'molecule_atom_index_0_z_1_mean', #1.39602
    'molecule_atom_index_0_z_1_mean_diff', #1.38955
#     'molecule_atom_index_0_z_1_mean_div', #1.39051
#     'molecule_atom_index_0_z_1_max', #1.3916
#     'molecule_atom_index_0_z_1_max_diff', #1.39117
#     'molecule_atom_index_0_z_1_max_div', # 1.39023
    'molecule_atom_index_0_z_1_std', #1.386
    'molecule_atom_index_0_z_1_std_diff', #1.38391
    'molecule_atom_index_0_z_1_std_div', #1.38061
#     'molecule_atom_index_0_z_1_min', #1.38672
#     'molecule_atom_index_0_z_1_min_diff', #1.38205
#     'molecule_atom_index_0_z_1_min_div', # 1.38852
    'molecule_atom_index_0_dist_mean', #1.33642
    'molecule_atom_index_0_dist_mean_diff', #1.33112
#     'molecule_atom_index_0_dist_mean_div', #1.33561
#     'molecule_atom_index_0_dist_max', # dont include
#     'molecule_atom_index_0_dist_max_diff', #1.33152
    'molecule_atom_index_0_dist_max_div', #1.32957, 1.32957
    'molecule_atom_index_0_dist_std',  #1.30413
    'molecule_atom_index_0_dist_std_diff', #1.30016
    'molecule_atom_index_0_dist_std_div', #1.29717
#     'molecule_atom_index_0_dist_min', # dont include
    'molecule_atom_index_0_dist_min_diff', #1.29138
#     'molecule_atom_index_0_dist_min_div', #1.29216
#     'molecule_atom_index_0_dist_x_mean', #1.2965
#     'molecule_atom_index_0_dist_x_mean_diff', #1.29559
#     'molecule_atom_index_0_dist_x_mean_div', #1.29204
#     'molecule_atom_index_0_dist_x_max', #1.29707
#     'molecule_atom_index_0_dist_x_max_diff', #1.29277
#     'molecule_atom_index_0_dist_x_max_div', #1.29328
#     'molecule_atom_index_0_dist_x_std', #1.2935
#     'molecule_atom_index_0_dist_x_std_diff', #1.29336
#     'molecule_atom_index_0_dist_x_std_div', #1.29492
#     'molecule_atom_index_0_dist_x_min', #1.29592
#     'molecule_atom_index_0_dist_x_min_diff', #1.29353
#     'molecule_atom_index_0_dist_x_min_div', #1.29338
#     'molecule_atom_index_0_dist_y_mean',
#     'molecule_atom_index_0_dist_y_mean_diff',
#     'molecule_atom_index_0_dist_y_mean_div',
#     'molecule_atom_index_0_dist_y_max',
#     'molecule_atom_index_0_dist_y_max_diff',
#     'molecule_atom_index_0_dist_y_max_div',
#     'molecule_atom_index_0_dist_y_std',
#     'molecule_atom_index_0_dist_y_std_diff',
#     'molecule_atom_index_0_dist_y_std_div',
#     'molecule_atom_index_0_dist_y_min',
#     'molecule_atom_index_0_dist_y_min_diff',
#     'molecule_atom_index_0_dist_y_min_div',
#     'molecule_atom_index_0_dist_z_mean',
#     'molecule_atom_index_0_dist_z_mean_diff',
#     'molecule_atom_index_0_dist_z_mean_div',
#     'molecule_atom_index_0_dist_z_max',
#     'molecule_atom_index_0_dist_z_max_diff',
#     'molecule_atom_index_0_dist_z_max_div',
#     'molecule_atom_index_0_dist_z_std',
#     'molecule_atom_index_0_dist_z_std_diff',
#     'molecule_atom_index_0_dist_z_std_div',
#     'molecule_atom_index_0_dist_z_min',
#     'molecule_atom_index_0_dist_z_min_diff',
#     'molecule_atom_index_0_dist_z_min_div',
#     'molecule_atom_index_1_x_1_mean',
#     'molecule_atom_index_1_x_1_mean_diff',
#     'molecule_atom_index_1_x_1_mean_div',
#     'molecule_atom_index_1_x_1_max',
#     'molecule_atom_index_1_x_1_max_diff',
#     'molecule_atom_index_1_x_1_max_div',
#     'molecule_atom_index_1_x_1_std',
#     'molecule_atom_index_1_x_1_std_diff',
#     'molecule_atom_index_1_x_1_std_div',
#     'molecule_atom_index_1_x_1_min',
#     'molecule_atom_index_1_x_1_min_diff',
#     'molecule_atom_index_1_x_1_min_div',
#     'molecule_atom_index_1_y_1_mean',
#     'molecule_atom_index_1_y_1_mean_diff',
#     'molecule_atom_index_1_y_1_mean_div',
#     'molecule_atom_index_1_y_1_max',
#     'molecule_atom_index_1_y_1_max_diff',
#     'molecule_atom_index_1_y_1_max_div',
#     'molecule_atom_index_1_y_1_std',
#     'molecule_atom_index_1_y_1_std_diff',
#     'molecule_atom_index_1_y_1_std_div',
#     'molecule_atom_index_1_y_1_min',
#     'molecule_atom_index_1_y_1_min_diff',
#     'molecule_atom_index_1_y_1_min_div',
#     'molecule_atom_index_1_z_1_mean',
#     'molecule_atom_index_1_z_1_mean_diff',
#     'molecule_atom_index_1_z_1_mean_div',
#     'molecule_atom_index_1_z_1_max',
#     'molecule_atom_index_1_z_1_max_diff',
#     'molecule_atom_index_1_z_1_max_div',
#     'molecule_atom_index_1_z_1_std',
#     'molecule_atom_index_1_z_1_std_diff',
#     'molecule_atom_index_1_z_1_std_div',
#     'molecule_atom_index_1_z_1_min',
#     'molecule_atom_index_1_z_1_min_diff',
#     'molecule_atom_index_1_z_1_min_div',
#     'molecule_atom_index_1_dist_mean',
#     'molecule_atom_index_1_dist_mean_diff',
#     'molecule_atom_index_1_dist_mean_div',
#     'molecule_atom_index_1_dist_max',
#     'molecule_atom_index_1_dist_max_diff',
#     'molecule_atom_index_1_dist_max_div',
#     'molecule_atom_index_1_dist_std',
#     'molecule_atom_index_1_dist_std_diff',
#     'molecule_atom_index_1_dist_std_div',
#     'molecule_atom_index_1_dist_min',
#     'molecule_atom_index_1_dist_min_diff',
#     'molecule_atom_index_1_dist_min_div',
#     'molecule_atom_index_1_dist_x_mean',
#     'molecule_atom_index_1_dist_x_mean_diff',
#     'molecule_atom_index_1_dist_x_mean_div',
#     'molecule_atom_index_1_dist_x_max',
#     'molecule_atom_index_1_dist_x_max_diff',
#     'molecule_atom_index_1_dist_x_max_div',
#     'molecule_atom_index_1_dist_x_std',
#     'molecule_atom_index_1_dist_x_std_diff',
#     'molecule_atom_index_1_dist_x_std_div',
#     'molecule_atom_index_1_dist_x_min',
#     'molecule_atom_index_1_dist_x_min_diff',
#     'molecule_atom_index_1_dist_x_min_div',
#     'molecule_atom_index_1_dist_y_mean',
#     'molecule_atom_index_1_dist_y_mean_diff',
#     'molecule_atom_index_1_dist_y_mean_div',
#     'molecule_atom_index_1_dist_y_max',
#     'molecule_atom_index_1_dist_y_max_diff',
#     'molecule_atom_index_1_dist_y_max_div',
#     'molecule_atom_index_1_dist_y_std',
#     'molecule_atom_index_1_dist_y_std_diff',
#     'molecule_atom_index_1_dist_y_std_div',
#     'molecule_atom_index_1_dist_y_min',
#     'molecule_atom_index_1_dist_y_min_diff',
#     'molecule_atom_index_1_dist_y_min_div',
#     'molecule_atom_index_1_dist_z_mean',
#     'molecule_atom_index_1_dist_z_mean_diff',
#     'molecule_atom_index_1_dist_z_mean_div',
#     'molecule_atom_index_1_dist_z_max',
#     'molecule_atom_index_1_dist_z_max_diff',
#     'molecule_atom_index_1_dist_z_max_div',
#     'molecule_atom_index_1_dist_z_std',
#     'molecule_atom_index_1_dist_z_std_diff',
#     'molecule_atom_index_1_dist_z_std_div',
#     'molecule_atom_index_1_dist_z_min',
#     'molecule_atom_index_1_dist_z_min_diff',
#     'molecule_atom_index_1_dist_z_min_div',
#     'molecule_type_x_1_mean',
#     'molecule_type_x_1_mean_diff',
#     'molecule_type_x_1_mean_div',
#     'molecule_type_x_1_max',
#     'molecule_type_x_1_max_diff',
#     'molecule_type_x_1_max_div',
#     'molecule_type_x_1_std',
#     'molecule_type_x_1_std_diff',
#     'molecule_type_x_1_std_div',
#     'molecule_type_x_1_min',
#     'molecule_type_x_1_min_diff',
#     'molecule_type_x_1_min_div',
#     'molecule_type_y_1_mean',
#     'molecule_type_y_1_mean_diff',
#     'molecule_type_y_1_mean_div',
#     'molecule_type_y_1_max',
#     'molecule_type_y_1_max_diff',
#     'molecule_type_y_1_max_div',
#     'molecule_type_y_1_std',
#     'molecule_type_y_1_std_diff',
#     'molecule_type_y_1_std_div',
#     'molecule_type_y_1_min',
#     'molecule_type_y_1_min_diff',
#     'molecule_type_y_1_min_div',
#     'molecule_type_z_1_mean',
#     'molecule_type_z_1_mean_diff',
#     'molecule_type_z_1_mean_div',
#     'molecule_type_z_1_max',
#     'molecule_type_z_1_max_diff',
#     'molecule_type_z_1_max_div',
#     'molecule_type_z_1_std',
#     'molecule_type_z_1_std_diff',
#     'molecule_type_z_1_std_div',
#     'molecule_type_z_1_min',
#     'molecule_type_z_1_min_diff',
#     'molecule_type_z_1_min_div',
#     'molecule_type_dist_mean',
#     'molecule_type_dist_mean_diff',
#     'molecule_type_dist_mean_div',
#     'molecule_type_dist_max',
#     'molecule_type_dist_max_diff',
#     'molecule_type_dist_max_div',
#     'molecule_type_dist_std',
#     'molecule_type_dist_std_diff',
#     'molecule_type_dist_std_div',
#     'molecule_type_dist_min',
#     'molecule_type_dist_min_diff',
#     'molecule_type_dist_min_div',
#     'molecule_type_dist_x_mean',
#     'molecule_type_dist_x_mean_diff',
#     'molecule_type_dist_x_mean_div',
#     'molecule_type_dist_x_max',
#     'molecule_type_dist_x_max_diff',
#     'molecule_type_dist_x_max_div',
#     'molecule_type_dist_x_std',
#     'molecule_type_dist_x_std_diff',
#     'molecule_type_dist_x_std_div',
#     'molecule_type_dist_x_min',
#     'molecule_type_dist_x_min_diff',
#     'molecule_type_dist_x_min_div',
#     'molecule_type_dist_y_mean',
#     'molecule_type_dist_y_mean_diff',
#     'molecule_type_dist_y_mean_div',
#     'molecule_type_dist_y_max',
#     'molecule_type_dist_y_max_diff',
#     'molecule_type_dist_y_max_div',
#     'molecule_type_dist_y_std',
#     'molecule_type_dist_y_std_diff',
#     'molecule_type_dist_y_std_div',
#     'molecule_type_dist_y_min',
#     'molecule_type_dist_y_min_diff',
#     'molecule_type_dist_y_min_div',
#     'molecule_type_dist_z_mean',
#     'molecule_type_dist_z_mean_diff',
#     'molecule_type_dist_z_mean_div',
#     'molecule_type_dist_z_max',
#     'molecule_type_dist_z_max_diff',
#     'molecule_type_dist_z_max_div',
#     'molecule_type_dist_z_std',
#     'molecule_type_dist_z_std_diff',
#     'molecule_type_dist_z_std_div',
#     'molecule_type_dist_z_min',
#     'molecule_type_dist_z_min_diff',
#     'molecule_type_dist_z_min_div',
#     'molecule_atom_1_x_1_mean',
#     'molecule_atom_1_x_1_mean_diff',
#     'molecule_atom_1_x_1_mean_div',
#     'molecule_atom_1_x_1_max',
#     'molecule_atom_1_x_1_max_diff',
#     'molecule_atom_1_x_1_max_div',
#     'molecule_atom_1_x_1_std',
#     'molecule_atom_1_x_1_std_diff',
#     'molecule_atom_1_x_1_std_div',
#     'molecule_atom_1_x_1_min',
#     'molecule_atom_1_x_1_min_diff',
#     'molecule_atom_1_x_1_min_div',
#     'molecule_atom_1_y_1_mean',
#     'molecule_atom_1_y_1_mean_diff',
#     'molecule_atom_1_y_1_mean_div',
#     'molecule_atom_1_y_1_max',
#     'molecule_atom_1_y_1_max_diff',
#     'molecule_atom_1_y_1_max_div',
#     'molecule_atom_1_y_1_std',
#     'molecule_atom_1_y_1_std_diff',
#     'molecule_atom_1_y_1_std_div',
#     'molecule_atom_1_y_1_min',
#     'molecule_atom_1_y_1_min_diff',
#     'molecule_atom_1_y_1_min_div',
#     'molecule_atom_1_z_1_mean',
#     'molecule_atom_1_z_1_mean_diff',
#     'molecule_atom_1_z_1_mean_div',
#     'molecule_atom_1_z_1_max',
#     'molecule_atom_1_z_1_max_diff',
#     'molecule_atom_1_z_1_max_div',
#     'molecule_atom_1_z_1_std',
#     'molecule_atom_1_z_1_std_diff',
#     'molecule_atom_1_z_1_std_div',
#     'molecule_atom_1_z_1_min',
#     'molecule_atom_1_z_1_min_diff',
#     'molecule_atom_1_z_1_min_div',
#     'molecule_atom_1_dist_mean',
#     'molecule_atom_1_dist_mean_diff',
#     'molecule_atom_1_dist_mean_div',
#     'molecule_atom_1_dist_max',
#     'molecule_atom_1_dist_max_diff',
#     'molecule_atom_1_dist_max_div',
#     'molecule_atom_1_dist_std',
#     'molecule_atom_1_dist_std_diff',
#     'molecule_atom_1_dist_std_div',
#     'molecule_atom_1_dist_min',
#     'molecule_atom_1_dist_min_diff',
#     'molecule_atom_1_dist_min_div',
#     'molecule_atom_1_dist_x_mean',
#     'molecule_atom_1_dist_x_mean_diff',
#     'molecule_atom_1_dist_x_mean_div',
#     'molecule_atom_1_dist_x_max',
#     'molecule_atom_1_dist_x_max_diff',
#     'molecule_atom_1_dist_x_max_div',
#     'molecule_atom_1_dist_x_std',
#     'molecule_atom_1_dist_x_std_diff',
#     'molecule_atom_1_dist_x_std_div',
#     'molecule_atom_1_dist_x_min',
#     'molecule_atom_1_dist_x_min_diff',
#     'molecule_atom_1_dist_x_min_div',
#     'molecule_atom_1_dist_y_mean',
#     'molecule_atom_1_dist_y_mean_diff',
#     'molecule_atom_1_dist_y_mean_div',
#     'molecule_atom_1_dist_y_max',
#     'molecule_atom_1_dist_y_max_diff',
#     'molecule_atom_1_dist_y_max_div',
#     'molecule_atom_1_dist_y_std',
#     'molecule_atom_1_dist_y_std_diff',
#     'molecule_atom_1_dist_y_std_div',
#     'molecule_atom_1_dist_y_min',
#     'molecule_atom_1_dist_y_min_diff',
#     'molecule_atom_1_dist_y_min_div',
#     'molecule_atom_1_dist_z_mean',
#     'molecule_atom_1_dist_z_mean_diff',
#     'molecule_atom_1_dist_z_mean_div',
#     'molecule_atom_1_dist_z_max',
#     'molecule_atom_1_dist_z_max_diff',
#     'molecule_atom_1_dist_z_max_div',
#     'molecule_atom_1_dist_z_std',
#     'molecule_atom_1_dist_z_std_diff',
#     'molecule_atom_1_dist_z_std_div',
#     'molecule_atom_1_dist_z_min',
#     'molecule_atom_1_dist_z_min_diff',
#     'molecule_atom_1_dist_z_min_div',
#     'molecule_type_0_x_1_mean',
#     'molecule_type_0_x_1_mean_diff',
#     'molecule_type_0_x_1_mean_div',
#     'molecule_type_0_x_1_max',
#     'molecule_type_0_x_1_max_diff',
#     'molecule_type_0_x_1_max_div',
#     'molecule_type_0_x_1_std',
#     'molecule_type_0_x_1_std_diff',
#     'molecule_type_0_x_1_std_div',
#     'molecule_type_0_x_1_min',
#     'molecule_type_0_x_1_min_diff',
#     'molecule_type_0_x_1_min_div',
#     'molecule_type_0_y_1_mean',
#     'molecule_type_0_y_1_mean_diff',
#     'molecule_type_0_y_1_mean_div',
#     'molecule_type_0_y_1_max',
#     'molecule_type_0_y_1_max_diff',
#     'molecule_type_0_y_1_max_div',
#     'molecule_type_0_y_1_std',
#     'molecule_type_0_y_1_std_diff',
#     'molecule_type_0_y_1_std_div',
#     'molecule_type_0_y_1_min',
#     'molecule_type_0_y_1_min_diff',
#     'molecule_type_0_y_1_min_div',
#     'molecule_type_0_z_1_mean',
#     'molecule_type_0_z_1_mean_diff',
#     'molecule_type_0_z_1_mean_div',
#     'molecule_type_0_z_1_max',
#     'molecule_type_0_z_1_max_diff',
#     'molecule_type_0_z_1_max_div',
#     'molecule_type_0_z_1_std',
#     'molecule_type_0_z_1_std_diff',
#     'molecule_type_0_z_1_std_div',
#     'molecule_type_0_z_1_min',
#     'molecule_type_0_z_1_min_diff',
#     'molecule_type_0_z_1_min_div',
#     'molecule_type_0_dist_mean',
#     'molecule_type_0_dist_mean_diff',
#     'molecule_type_0_dist_mean_div',
#     'molecule_type_0_dist_max',
#     'molecule_type_0_dist_max_diff',
#     'molecule_type_0_dist_max_div',
#     'molecule_type_0_dist_std',
#     'molecule_type_0_dist_std_diff',
#     'molecule_type_0_dist_std_div',
#     'molecule_type_0_dist_min',
#     'molecule_type_0_dist_min_diff',
#     'molecule_type_0_dist_min_div',
#     'molecule_type_0_dist_x_mean',
#     'molecule_type_0_dist_x_mean_diff',
#     'molecule_type_0_dist_x_mean_div',
#     'molecule_type_0_dist_x_max',
#     'molecule_type_0_dist_x_max_diff',
#     'molecule_type_0_dist_x_max_div',
#     'molecule_type_0_dist_x_std',
#     'molecule_type_0_dist_x_std_diff',
#     'molecule_type_0_dist_x_std_div',
#     'molecule_type_0_dist_x_min',
#     'molecule_type_0_dist_x_min_diff',
#     'molecule_type_0_dist_x_min_div',
#     'molecule_type_0_dist_y_mean',
#     'molecule_type_0_dist_y_mean_diff',
#     'molecule_type_0_dist_y_mean_div',
#     'molecule_type_0_dist_y_max',
#     'molecule_type_0_dist_y_max_diff',
#     'molecule_type_0_dist_y_max_div',
#     'molecule_type_0_dist_y_std',
#     'molecule_type_0_dist_y_std_diff',
#     'molecule_type_0_dist_y_std_div',
#     'molecule_type_0_dist_y_min',
#     'molecule_type_0_dist_y_min_diff',
#     'molecule_type_0_dist_y_min_div',
#     'molecule_type_0_dist_z_mean',
#     'molecule_type_0_dist_z_mean_diff',
#     'molecule_type_0_dist_z_mean_div',
#     'molecule_type_0_dist_z_max',
#     'molecule_type_0_dist_z_max_diff',
#     'molecule_type_0_dist_z_max_div',
#     'molecule_type_0_dist_z_std',
#     'molecule_type_0_dist_z_std_diff',
#     'molecule_type_0_dist_z_std_div',
#     'molecule_type_0_dist_z_min',
#     'molecule_type_0_dist_z_min_diff',
#     'molecule_type_0_dist_z_min_div'

]

# %%
# for f in ['atom_0', 'type_1']:
# #     if f in good_columns:
#     lbl = LabelEncoder()
#     lbl.fit(list(X[f].values) + list(X_test[f].values))
#     X[f] = lbl.transform(list(X[f].values))
#     X_test[f] = lbl.transform(list(X_test[f].values))

# %%
# X = train[good_columns].copy()
# y = train['scalar_coupling_constant']
# X_test = test[good_columns].copy()

# %%
# X = train.copy()
# y = train['scalar_coupling_constant']
# del train

# X_test = test.copy()
# del test
# del structures

# %%
# X = X.drop(['id', 'molecule_name', 'scalar_coupling_constant'], axis=1)

# X_test = X_test.drop(['id', 'molecule_name'], axis=1)

# %%
X = train[good_columns].copy()
y = train['scalar_coupling_constant']
X_test = test[good_columns].copy()

# %%
# del train, test

# %%
import gc
gc.collect()
# Out:
# 404

# %%
# n_fold = 5
n_fold = 5
folds = KFold(n_splits=n_fold, shuffle=True, random_state=11)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-255-e34834da9b73> in <module>()
#       1 # n_fold = 5
#       2 n_fold = 1
# ----> 3 folds = KFold(n_splits=n_fold, shuffle=True, random_state=11)
#
# ~/anaconda3/envs/pmp/lib/python3.6/site-packages/sklearn/model_selection/_split.py in __init__(self, n_splits, shuffle, random_state)
#     417     def __init__(self, n_splits=3, shuffle=False,
#     418                  random_state=None):
# --> 419         super(KFold, self).__init__(n_splits, shuffle, random_state)
#     420
#     421     def _iter_test_indices(self, X, y=None, groups=None):
#
# ~/anaconda3/envs/pmp/lib/python3.6/site-packages/sklearn/model_selection/_split.py in __init__(self, n_splits, shuffle, random_state)
#     282                 "k-fold cross-validation requires at least one"
#     283                 " train/test split by setting n_splits=2 or more,"
# --> 284                 " got n_splits={0}.".format(n_splits))
#     285
#     286         if not isinstance(shuffle, bool):
#
# ValueError: k-fold cross-validation requires at least one train/test split by setting n_splits=2 or more, got n_splits=1.

# %%
# CV mean score: -0.2405, std: 0.0013. - just by adding dxy, dyz, dxz and sin and cos
# CV mean score: -0.2547, std: 0.0028 - used dxy, dyz, dxz, molecule_dxy_mean etc
# CV mean score: -0.2516, std: 0.0019. - molecule_atom_index_0_dxy_min etc
# CV mean score: -0.2224, std: 0.0019. - 'molecule_atom_index_1_dist_z_min'
# CV mean score: -0.2730, std: 0.0015 - 'dx', 'dy', 'dz', 'r', 'dxz', 'dyz'
# CV mean score: -0.2685, std: 0.0016.: above + 'phi','phi_deg','z1', 'z2', 'theta', 'theta_deg',
# CV mean score: -0.2693, std: 0.0014.: 'x1','x2','y1','y2',
# CV mean score: -0.2677, std: 0.0012.: 'sin_theta','cos_theta', 'sin_phi', 'cos_phi',

# %%
X_test.shape
# Out:
# (2505542, 48)

# %%
good_cols = good_columns

# %%
tested_cols = [
    'molecule_atom_index_0_dist_min',
    'molecule_atom_index_0_dist_max', # 24.42
    'atom_index_0', #24.3873
    'atom_index_1', #16.8178
    'type', #2.18402
    'atom_0' #2.18402
    'x_0', #2.15712
    'y_0', #2.10615
    'z_0', #2.08603
    'atom_1', #2.08291
    'x_1', #1.99933
    'y_1', #1.95652
    'z_1', #1.89673
    'dist', #1.59632
    'dist_x', #1.59741
    'dist_y', #1.59478
    'dist_z', #1.59505
    'dx', #1.59686
    'dy', #1.59676
    'dz', #1.59694
    'r', #1.59287
    'phi' #1.59777
    'phi_deg', #1.59672
    'z1', #1.5956
    'z2', #1.5991
    'theta', # 1.59975
    'theta_deg' #1.59734
    'x1', #1.59675
    'x2', #1.59679
    'y1', #1.59991
    'y2', #1.5986
    'sin_theta', #1.59712
    'cos_theta', #1.5956
    'sin_phi', #1.5986
    'cos_phi' #1.59679
    'dyz', #1.59809
    'dxz', #1.59695
    'type_0', #1.59287
    'type_1', # 1.59287
    'molecule_couples', #1.55716
    'molecule_dist_mean', #1.53695
    'molecule_dist_min', #1.52542
    'molecule_dist_max', #1.51814,
    'molecule_dist_std', #1.51487
    'atom_0_couples_count', #1.46383
    'atom_1_couples_count', #1.43409
    'type_0_couples_count', #1.4352
    'type_1_couples_count', #1.43095
    'molecule_dxy_mean', #1.43301
    'molecule_dxy_min', #1.43352
    'molecule_dxy_max', # 1.4334
    'molecule_dxy_std', #1.43231
    'molecule_dyz_mean', #1.43037
    'molecule_dyz_min', #1.43093
    'molecule_dyz_max', #1.43452
    'molecule_dyz_std', #1.43188
    'molecule_dxz_mean', #1.43007
    'molecule_dxz_min', #1.43067
    'molecule_dxz_max', #1.43559
    'molecule_dxz_std', #1.43229
    'molecule_atom_index_0_count', #1.43007
    'molecule_atom_index_1_count', #1.43007
    'molecule_type_count', #1.43007
    'molecule_atom_1_count', #1.43007
    'molecule_type_0_count', #1.43007
    'molecule_atom_index_0_x_1_mean', #1.42564
    'molecule_atom_index_0_x_1_mean_diff', #1.42405
    'molecule_atom_index_0_x_1_mean_div', #1.42634
    'molecule_atom_index_0_x_1_max', #1.4263
    'molecule_atom_index_0_x_1_max_diff', #1.4161
    'molecule_atom_index_0_x_1_max_div', #1.4226
    'molecule_atom_index_0_x_1_std', # 1.42286
    'molecule_atom_index_0_x_1_std_diff', #1.4253
    'molecule_atom_index_0_x_1_std_div', #1.42493
    'molecule_atom_index_0_x_1_min', #1.42229
    'molecule_atom_index_0_x_1_min_diff', #1.42594
    'molecule_atom_index_0_x_1_min_div', #1.42024
    'molecule_atom_index_0_y_1_mean', #1.41604
    'molecule_atom_index_0_y_1_mean_diff', #1.41118
    'molecule_atom_index_0_y_1_mean_div', #1.41211
    'molecule_atom_index_0_y_1_max', #1.40826
    'molecule_atom_index_0_y_1_max_diff', #1.40184
    'molecule_atom_index_0_y_1_max_div', #1.406
    'molecule_atom_index_0_y_1_std', # 1.40109
    'molecule_atom_index_0_y_1_std_diff', #1.39787
    'molecule_atom_index_0_y_1_std_div', #1.401
    'molecule_atom_index_0_y_1_min', #1.39971
    'molecule_atom_index_0_y_1_min_diff', #1.39624
    'molecule_atom_index_0_y_1_min_div', #1.39703
    'molecule_atom_index_0_z_1_mean', #1.39602
    'molecule_atom_index_0_z_1_mean_diff', #1.38955
    'molecule_atom_index_0_z_1_mean_div', #1.39051
    'molecule_atom_index_0_z_1_max', #1.3916
    'molecule_atom_index_0_z_1_max_diff', #1.39117
    'molecule_atom_index_0_z_1_max_div', # 1.39023
    'molecule_atom_index_0_z_1_std', #1.386
    'molecule_atom_index_0_z_1_std_diff', #1.38391
    'molecule_atom_index_0_z_1_std_div', #1.38061
    'molecule_atom_index_0_z_1_min', #1.38672
    'molecule_atom_index_0_z_1_min_diff', #1.38205
    'molecule_atom_index_0_z_1_min_div', # 1.38852
    'molecule_atom_index_0_dist_mean', #1.33642
    'molecule_atom_index_0_dist_mean_diff', #1.33112
    'molecule_atom_index_0_dist_mean_div', #1.33561
    'molecule_atom_index_0_dist_max', # dont include
    'molecule_atom_index_0_dist_max_diff', #1.33152
    'molecule_atom_index_0_dist_max_div', #1.32957, 1.32957
    'molecule_atom_index_0_dist_std',  #1.30413
    'molecule_atom_index_0_dist_std_diff', #1.30016
    'molecule_atom_index_0_dist_std_div', #1.29717
    'molecule_atom_index_0_dist_min', # dont include
    'molecule_atom_index_0_dist_min_diff', #1.29138
    'molecule_atom_index_0_dist_min_div', #1.29216
    'molecule_atom_index_0_dist_x_mean', #1.2965
    'molecule_atom_index_0_dist_x_mean_diff', #1.29559
    'molecule_atom_index_0_dist_x_mean_div', #1.29204
    'molecule_atom_index_0_dist_x_max', #1.29707
    'molecule_atom_index_0_dist_x_max_diff', #1.29277
    'molecule_atom_index_0_dist_x_max_div', #1.29328
    'molecule_atom_index_0_dist_x_std', #1.2935
    'molecule_atom_index_0_dist_x_std_diff', #1.29336
    'molecule_atom_index_0_dist_x_std_div', #1.29492
    'molecule_atom_index_0_dist_x_min', #1.29592
    'molecule_atom_index_0_dist_x_min_diff', #1.29353
    'molecule_atom_index_0_dist_x_min_div', #1.29338
]

# %%
remaining_cols = list(set(list(train.columns)) - set(tested_cols))

# %%
t = ['1', 'a']
t.append('b')
t
# Out:
# ['1', 'a', 'b']

# %%
min_score = 0.11030484411538387

# %%
from artgor_utils import *
from tqdm import tqdm_notebook

# %%
skip_cols = ['id', 'molecule_name', 'scalar_coupling_constant']

# %%
for col in tqdm_notebook(remaining_cols):
    if col in skip_cols:
        continue
    good_cols = good_columns.copy()
    good_cols.append(col)
    X = train[good_cols].copy()
    y = train['scalar_coupling_constant']
    X_test = test[good_cols].copy()
    
    params = {'num_leaves': 128,
          'min_child_samples': 79,
          'objective': 'regression',
          'max_depth': 9,
          'learning_rate': 0.2,
          "boosting_type": "gbdt",
          "subsample_freq": 1,
          "subsample": 0.9,
          "bagging_seed": 11,
          "metric": 'mae',
          "verbosity": -1,
          'reg_alpha': 0.1,
          'reg_lambda': 0.3,
          'colsample_bytree': 1.0
         }
    result_dict_lgb = train_model_regression2(X=X, X_test=X_test, y=y, params=params, folds=folds, 
                                             model_type='lgb', eval_metric='group_mae', 
                                             plot_feature_importance=False,
                                             verbose=500, early_stopping_rounds=200, n_estimators=500)

    curr_score = result_dict_lgb['scores'][0]
    if curr_score < min_score:
        good_columns.append(col)
        min_score = curr_score
        print('{} added'.format(col))
    else:
        print('{} not added'.format(col))
    print(result_dict_lgb['scores'], min_score)
#     break
# Out:
# HBox(children=(IntProgress(value=0, max=372), HTML(value='')))
# Fold 1 started at Tue Jun 18 20:21:37 2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 1.24343	valid_1's l1: 1.29265
# Did not meet early stopping. Best iteration is:
# [500]	training's l1: 1.24343	valid_1's l1: 1.29265
# molecule_type_0_dist_mean_diff not added
# [0.11443555008343163] 0.11030484411538387
# Fold 1 started at Tue Jun 18 20:24:04 2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 1.24556	valid_1's l1: 1.29363
# Did not meet early stopping. Best iteration is:
# [500]	training's l1: 1.24556	valid_1's l1: 1.29363
# molecule_atom_1_x_1_min not added
# [0.11119413409538464] 0.11030484411538387
# Fold 1 started at Tue Jun 18 20:26:06 2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 1.24732	valid_1's l1: 1.29609
# Did not meet early stopping. Best iteration is:
# [500]	training's l1: 1.24732	valid_1's l1: 1.29609
# molecule_atom_index_1_dist_z_min_diff not added
# [0.12073359808132333] 0.11030484411538387
# Fold 1 started at Tue Jun 18 20:28:05 2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 1.24355	valid_1's l1: 1.29184
# Did not meet early stopping. Best iteration is:
# [500]	training's l1: 1.24355	valid_1's l1: 1.29184
# molecule_type_0_dist_y_min_diff not added
# [0.11035044805691105] 0.11030484411538387
# Fold 1 started at Tue Jun 18 20:30:05 2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 1.24444	valid_1's l1: 1.29283
# Did not meet early stopping. Best iteration is:
# [500]	training's l1: 1.24444	valid_1's l1: 1.29283
# molecule_atom_index_1_dist_y_mean_div not added
# [0.11121785184517943] 0.11030484411538387
# Fold 1 started at Tue Jun 18 20:32:04 2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 1.24552	valid_1's l1: 1.29406
# Did not meet early stopping. Best iteration is:
# [500]	training's l1: 1.24552	valid_1's l1: 1.29406
# molecule_type_0_y_1_mean_div not added
# [0.11643303377881242] 0.11030484411538387
# Fold 1 started at Tue Jun 18 20:34:03 2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 1.2461	valid_1's l1: 1.29427
# Did not meet early stopping. Best iteration is:
# [500]	training's l1: 1.2461	valid_1's l1: 1.29427
# molecule_type_dist_y_mean not added
# [0.11387774360680532] 0.11030484411538387
# Fold 1 started at Tue Jun 18 20:36:00 2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 1.24574	valid_1's l1: 1.29388
# Did not meet early stopping. Best iteration is:
# [500]	training's l1: 1.24574	valid_1's l1: 1.29388
# x1 added
# [0.11007195082413385] 0.11007195082413385
# Fold 1 started at Tue Jun 18 20:37:58 2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 1.2465	valid_1's l1: 1.29417
# Did not meet early stopping. Best iteration is:
# [500]	training's l1: 1.2465	valid_1's l1: 1.29417
# molecule_type_z_1_std not added
# [0.11761953268898268] 0.11007195082413385
# Fold 1 started at Tue Jun 18 20:40:01 2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 1.24716	valid_1's l1: 1.29546
# Did not meet early stopping. Best iteration is:
# [500]	training's l1: 1.24716	valid_1's l1: 1.29546
# molecule_type_x_1_std not added
# [0.11953108082324662] 0.11007195082413385
# Fold 1 started at Tue Jun 18 20:42:04 2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 1.24443	valid_1's l1: 1.29253
# Did not meet early stopping. Best iteration is:
# [500]	training's l1: 1.24443	valid_1's l1: 1.29253
# molecule_type_dist_z_min_div not added
# [0.11295251782826171] 0.11007195082413385
# Fold 1 started at Tue Jun 18 20:44:08 2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 1.24695	valid_1's l1: 1.29604
# Did not meet early stopping. Best iteration is:
# [500]	training's l1: 1.24695	valid_1's l1: 1.29604
# molecule_atom_index_1_dist_z_max_div not added
# [0.12091997844782712] 0.11007195082413385
# Fold 1 started at Tue Jun 18 20:46:12 2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 1.24231	valid_1's l1: 1.2906
# Did not meet early stopping. Best iteration is:
# [500]	training's l1: 1.24231	valid_1's l1: 1.2906
# molecule_type_dist_z_min_diff not added
# [0.11202637428633849] 0.11007195082413385
# Fold 1 started at Tue Jun 18 20:48:16 2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 1.24406	valid_1's l1: 1.29311
# Did not meet early stopping. Best iteration is:
# [500]	training's l1: 1.24406	valid_1's l1: 1.29311
# molecule_atom_1_dist_max_diff not added
# [0.11288077128946289] 0.11007195082413385
# Fold 1 started at Tue Jun 18 20:50:19 2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 1.24399	valid_1's l1: 1.29273
# Did not meet early stopping. Best iteration is:
# [500]	training's l1: 1.24399	valid_1's l1: 1.29273
# molecule_atom_index_1_dist_y_min_div not added
# [0.1108435158596047] 0.11007195082413385
# Fold 1 started at Tue Jun 18 20:52:24 2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 1.24478	valid_1's l1: 1.29384
# Did not meet early stopping. Best iteration is:
# [500]	training's l1: 1.24478	valid_1's l1: 1.29384
# molecule_atom_1_z_1_mean_div not added
# [0.11254051022102289] 0.11007195082413385
# Fold 1 started at Tue Jun 18 20:54:27 2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 1.24712	valid_1's l1: 1.29586
# Did not meet early stopping. Best iteration is:
# [500]	training's l1: 1.24712	valid_1's l1: 1.29586
# molecule_atom_1_z_1_std_diff not added
# [0.11316274272449722] 0.11007195082413385
# Fold 1 started at Tue Jun 18 20:56:28 2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 1.24482	valid_1's l1: 1.29328
# Did not meet early stopping. Best iteration is:
# [500]	training's l1: 1.24482	valid_1's l1: 1.29328
# molecule_type_x_1_mean_diff not added
# [0.11241812613930519] 0.11007195082413385
# Fold 1 started at Tue Jun 18 20:58:30 2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 1.24674	valid_1's l1: 1.2966
# Did not meet early stopping. Best iteration is:
# [500]	training's l1: 1.24674	valid_1's l1: 1.2966
# molecule_type_dist_std_diff not added
# [0.11491245025520529] 0.11007195082413385
# Fold 1 started at Tue Jun 18 21:00:33 2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 1.24943	valid_1's l1: 1.29715
# Did not meet early stopping. Best iteration is:
# [500]	training's l1: 1.24943	valid_1's l1: 1.29715
# molecule_type_0_y_1_min not added
# [0.11405897863989145] 0.11007195082413385
# Fold 1 started at Tue Jun 18 21:02:35 2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 1.24758	valid_1's l1: 1.29611
# Did not meet early stopping. Best iteration is:
# [500]	training's l1: 1.24758	valid_1's l1: 1.29611
# molecule_atom_index_0_dist_z_mean_diff not added
# [0.11195298361599777] 0.11007195082413385
# Fold 1 started at Tue Jun 18 21:04:36 2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 1.24221	valid_1's l1: 1.28957
# Did not meet early stopping. Best iteration is:
# [500]	training's l1: 1.24221	valid_1's l1: 1.28957
# molecule_atom_index_0_dist_y_std_div added
# [0.10781002218190466] 0.10781002218190466
# Fold 1 started at Tue Jun 18 21:06:37 2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 1.24371	valid_1's l1: 1.29237
# Did not meet early stopping. Best iteration is:
# [500]	training's l1: 1.24371	valid_1's l1: 1.29237
# molecule_type_0_y_1_min_diff not added
# [0.11564770842357006] 0.10781002218190466
# Fold 1 started at Tue Jun 18 21:08:41 2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 1.24812	valid_1's l1: 1.29737
# Did not meet early stopping. Best iteration is:
# [500]	training's l1: 1.24812	valid_1's l1: 1.29737
# molecule_atom_index_1_dist_y_max_diff not added
# [0.112993040088221] 0.10781002218190466
# Fold 1 started at Tue Jun 18 21:10:44 2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 1.24396	valid_1's l1: 1.29232
# Did not meet early stopping. Best iteration is:
# [500]	training's l1: 1.24396	valid_1's l1: 1.29232
# molecule_atom_1_y_1_std not added
# [0.11213747874313687] 0.10781002218190466
# Fold 1 started at Tue Jun 18 21:12:51 2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 1
2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 1.24466	valid_1's l1: 1.29292
# Did not meet early stopping. Best iteration is:
# [500]	training's l1: 1.24466	valid_1's l1: 1.29292
# molecule_type_0_z_1_std not added
# [0.11285895084410823] 0.10556266915772915
# Fold 1 started at Tue Jun 18 21:46:29 2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 1.24585	valid_1's l1: 1.29503
# Did not meet early stopping. Best iteration is:
# [500]	training's l1: 1.24585	valid_1's l1: 1.29503
# molecule_type_0_y_1_max not added
# [0.1147351182622518] 0.10556266915772915
# Fold 1 started at Tue Jun 18 21:48:35 2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 1.24443	valid_1's l1: 1.29204
# Did not meet early stopping. Best iteration is:
# [500]	training's l1: 1.24443	valid_1's l1: 1.29204
# molecule_type_dist_mean_diff not added
# [0.11095462156040994] 0.10556266915772915
# Fold 1 started at Tue Jun 18 21:50:40 2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 1.24458	valid_1's l1: 1.29414
# Did not meet early stopping. Best iteration is:
# [500]	training's l1: 1.24458	valid_1's l1: 1.29414
# molecule_atom_index_1_dist_x_mean_div not added
# [0.11535031972248828] 0.10556266915772915
# Fold 1 started at Tue Jun 18 21:52:47 2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 1.24852	valid_1's l1: 1.29719
# Did not meet early stopping. Best iteration is:
# [500]	training's l1: 1.24852	valid_1's l1: 1.29719
# molecule_atom_1_x_1_mean_div not added
# [0.11585988351732887] 0.10556266915772915
# Fold 1 started at Tue Jun 18 21:54:54 2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 1.24782	valid_1's l1: 1.29661
# Did not meet early stopping. Best iteration is:
# [500]	training's l1: 1.24782	valid_1's l1: 1.29661
# molecule_type_0_x_1_min_div not added
# [0.11501530438741586] 0.10556266915772915
# Fold 1 started at Tue Jun 18 21:56:56 2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 1.24551	valid_1's l1: 1.29497
# Did not meet early stopping. Best iteration is:
# [500]	training's l1: 1.24551	valid_1's l1: 1.29497
# molecule_type_0_dist_y_max not added
# [0.11590227775725588] 0.10556266915772915
# Fold 1 started at Tue Jun 18 21:58:59 2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 1.24615	valid_1's l1: 1.29441
# Did not meet early stopping. Best iteration is:
# [500]	training's l1: 1.24615	valid_1's l1: 1.29441
# molecule_atom_1_dist_y_max_diff not added
# [0.11465239563305414] 0.10556266915772915
# Fold 1 started at Tue Jun 18 22:01:03 2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 1.24575	valid_1's l1: 1.29486
# Did not meet early stopping. Best iteration is:
# [500]	training's l1: 1.24575	valid_1's l1: 1.29486
# molecule_atom_index_1_dist_z_max_diff not added
# [0.11345409574796766] 0.10556266915772915
# Fold 1 started at Tue Jun 18 22:03:09 2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 1.24616	valid_1's l1: 1.29539
# Did not meet early stopping. Best iteration is:
# [500]	training's l1: 1.24616	valid_1's l1: 1.29539
# molecule_atom_index_1_dist_x_std_div not added
# [0.11442646722220357] 0.10556266915772915
# Fold 1 started at Tue Jun 18 22:05:15 2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 1.24645	valid_1's l1: 1.29524
# Did not meet early stopping. Best iteration is:
# [500]	training's l1: 1.24645	valid_1's l1: 1.29524
# molecule_type_0_x_1_std_diff not added
# [0.11152885451196615] 0.10556266915772915
# Fold 1 started at Tue Jun 18 22:07:21 2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 1.24335	valid_1's l1: 1.29203
# Did not meet early stopping. Best iteration is:
# [500]	training's l1: 1.24335	valid_1's l1: 1.29203
# molecule_atom_index_1_dist_y_max not added
# [0.11335741546120603] 0.10556266915772915
# Fold 1 started at Tue Jun 18 22:09:26 2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 1.24437	valid_1's l1: 1.29291
# Did not meet early stopping. Best iteration is:
# [500]	training's l1: 1.24437	valid_1's l1: 1.29291
# molecule_atom_1_dist_x_min not added
# [0.1146031302692101] 0.10556266915772915
# Fold 1 started at Tue Jun 18 22:11:32 2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 1.22366	valid_1's l1: 1.27346
# Did not meet early stopping. Best iteration is:
# [500]	training's l1: 1.22366	valid_1's l1: 1.27346
# molecule_atom_index_1_dist_max_diff added
# [0.10085192259246685] 0.10085192259246685
# Fold 1 started at Tue Jun 18 22:13:37 2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 1.22423	valid_1's l1: 1.27299
# Did not meet early stopping. Best iteration is:
# [500]	training's l1: 1.22423	valid_1's l1: 1.27299
# molecule_type_0_z_1_mean added
# [0.09746283209533402] 0.09746283209533402
# Fold 1 started at Tue Jun 18 22:15:44 2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 1.22372	valid_1's l1: 1.27357
# Did not meet early stopping. Best iteration is:
# [500]	training's l1: 1.22372	valid_1's l1: 1.27357
# molecule_atom_index_1_dist_y_min_diff not added
# [0.1020022328772946] 0.09746283209533402
# Fold 1 started at Tue Jun 18 22:17:52 2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 1.22423	valid_1's l1: 1.27299
# Did not meet early stopping. Best iteration is:
# [500]	training's l1: 1.22423	valid_1's l1: 1.27299
# molecule_atom_index_1_y_1_min_div added
# [0.09746068389565787] 0.09746068389565787
# Fold 1 started at Tue Jun 18 22:20:01 2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 1.2239	valid_1's l1: 1.27264
# Did not meet early stopping. Best iteration is:
# [500]	training's l1: 1.2239	valid_1's l1: 1.27264
# molecule_atom_index_1_dist_z_std added
# [0.0952802545417387] 0.0952802545417387
# Fold 1 started at Tue Jun 18 22:22:11 2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 1.18242	valid_1's l1: 1.23
# Did not meet early stopping. Best iteration is:
# [500]	training's l1: 1.18242	valid_1's l1: 1.23
# molecule_atom_index_1_dist_mean_diff added
# [0.07180947431625848] 0.07180947431625848
# Fold 1 started at Tue Jun 18 22:24:25 2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 1.18112	valid_1's l1: 1.22801
# Did not meet early stopping. Best iteration is:
# [500]	training's l1: 1.18112	valid_1's l1: 1.22801
# molecule_atom_1_x_1_max_diff added
# [0.06769071769825602] 0.06769071769825602
# Fold 1 started at Tue Jun 18 22:26:37 2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 1.1802	valid_1's l1: 1.22702
# Did not meet early stopping. Best iteration is:
# [500]	training's l1: 1.1802	valid_1's l1: 1.22702
# molecule_atom_index_0_dist_y_mean added
# [0.0657128670217729] 0.0657128670217729
# Fold 1 started at Tue Jun 18 22:28:49 2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 1.18321	valid_1's l1: 1.23072
# Did not meet early stopping. Best iteration is:
# [500]	training's l1: 1.18321	valid_1's l1: 1.23072
# molecule_atom_index_1_dist_z_std_diff not added
# [0.07251391496772101] 0.0657128670217729
# Fold 1 started at Tue Jun 18 22:31:03 2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 1.17751	valid_1's l1: 1.225
# Did not meet early stopping. Best iteration is:
# [500]	training's l1: 1.17751	valid_1's l1: 1.225
# molecule_atom_1_dist_z_max_div added
# [0.06481939019634651] 0.06481939019634651
# Fold 1 started at Tue Jun 18 22:33:16 2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 1.17877	valid_1's l1: 1.22776
# Did not meet early stopping. Best iteration is:
# [500]	training's l1: 1.17877	valid_1's l1: 1.22776
# molecule_type_dist_min_diff not added
# [0.06649385650307665] 0.06481939019634651
# Fold 1 started at Tue Jun 18 22:35:34 2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 1.1816	valid_1's l1: 1.22967
# Did not meet early stopping. Best iteration is:
# [500]	training's l1: 1.1816	valid_1's l1: 1.22967
# molecule_type_0_x_1_std not added
# [0.0726751726361051] 0.06481939019634651
# Fold 1 started at Tue Jun 18 22:37:53 2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 1.17751	valid_1's l1: 1.225
# Did not meet early stopping. Best iteration is:
# [500]	training's l1: 1.17751	valid_1's l1: 1.225
# molecule_atom_index_1_x_1_max_diff not added
# [0.06481939019645244] 0.06481939019634651
# Fold 1 started at Tue Jun 18 22:40:06 2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 1.18403	valid_1's l1: 1.23231
# Did not meet early stopping. Best iteration is:
# [500]	training's l1: 1.18403	valid_1's l1: 1.23231
# molecule_atom_1_z_1_std not added
# [0.07578095678221511] 0.06481939019634651
# Fold 1 started at Tue Jun 18 22:42:24 2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 1.18021	valid_1's l1: 1.22815
# Did not meet early stopping. Best iteration is:
# [500]	training's l1: 1.18021	valid_1's l1: 1.22815
# molecule_type_0_z_1_min_div not added
# [0.0688200565301193] 0.06481939019634651
# Fold 1 started at Tue Jun 18 22:44:41 2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 1.18004	valid_1's l1: 1.22818
# Did not meet early stopping. Best iteration is:
# [500]	training's l1: 1.18004	valid_1's l1: 1.22818
# molecule_type_0_dist_x_mean not added
# [0.07284965579077848] 0.06481939019634651
# Fold 1 started at Tue Jun 18 22:46:58 2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 1.1838	valid_1's l1: 1.23174
# Did not meet early stopping. Best iteration is:
# [500]	training's l1: 1.1838	valid_1's l1: 1.23174
# molecule_type_0_dist_mean not added
# [0.07219106573210633] 0.06481939019634651
# Fold 1 started at Tue Jun 18 22:49:12 2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 1.18105	valid_1's l1: 1.22956
# Did not meet early stopping. Best iteration is:
# [500]	training's l1: 1.18105	valid_1's l1: 1.22956
# molecule_atom_index_1_dist_x_max_div not added
# [0.0699090594970648] 0.06481939019634651
# Fold 1 started at Tue Jun 18 22:51:25 2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 1.18175	valid_1's l1: 1.23005
# Did not meet early stopping. Best iteration is:
# [500]	training's l1: 1.18175	valid_1's l1: 1.23005
# molecule_type_0_x_1_std_div not added
# [0.07089728056654704] 0.06481939019634651
# Fold 1 started at Tue Jun 18 22:53:41 2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 1.18429	valid_1's l1: 1.23258
# Did not meet early stopping. Best iteration is:
# [500]	training's l1: 1.18429	valid_1's l1: 1.23258
# molecule_type_dist_y_max not added
# [0.07627826124372905] 0.06481939019634651
# Fold 1 started at Tue Jun 18 22:55:55 2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 1.17865	valid_1's l1: 1.22685
# Did not meet early stopping. Best iteration is:
# [500]	training's l1: 1.17865	valid_1's l1: 1.22685
# molecule_type_0_z_1_min_diff not added
# [0.07181684504041747] 0.06481939019634651
# Fold 1 started at Tue Jun 18 22:58:10 2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 1.17628	valid_1's l1: 1.2251
# Did not meet early stopping. Best iteration is:
# [500]	training's l1: 1.17628	valid_1's l1: 1.2251
# molecule_type_0_z_1_mean_diff not added
# [0.06741563513259258] 0.06481939019634651
# Fold 1 started at Tue Jun 18 23:00:26 2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 1.17751	valid_1's l1: 1.225
# Did not meet early stopping. Best iteration is:
# [500]	training's l1: 1.17751	valid_1's l1: 1.225
# molecule_atom_index_1_y_1_mean not added
# [0.06481939019650342] 0.06481939019634651
# Fold 1 started at Tue Jun 18 23:02:41 2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 1.18137	valid_1's l1: 1.22933
# Did not meet early stopping. Best iteration is:
# [500]	training's l1: 1.18137	valid_1's l1: 1.22933
# molecule_atom_index_1_dist_mean_div not added
# [0.07278398608249562] 0.06481939019634651
# Fold 1 started at Tue Jun 18 23:04:57 2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 1.18293	valid_1's l1: 1.23053
# Did not meet early stopping. Best iteration is:
# [500]	training's l1: 1.18293	valid_1's l1: 1.23053
# molecule_type_dist_std_div not added
# [0.06678329548618818] 0.06481939019634651
# Fold 1 started at Tue Jun 18 23:07:13 2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 1.1791	valid_1's l1: 1.2274
# Did not meet early stopping. Best iteration is:
# [500]	training's l1: 1.1791	valid_1's l1: 1.2274
# molecule_atom_1_dist_x_min_div not added
# [0.06490599325615401] 0.06481939019634651
# Fold 1 started at Tue Jun 18 23:09:27 2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 1.18059	valid_1's l1: 1.22887
# Did not meet early stopping. Best iteration is:
# [500]	training's l1: 1.18059	valid_1's l1: 1.22887
# molecule_atom_1_x_1_max not added
# [0.07319524492011745] 0.06481939019634651
# Fold 1 started at Tue Jun 18 23:11:43 2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 1.17814	valid_1's l1: 1.22682
# Did not meet early stopping. Best iteration is:
# [500]	training's l1: 1.17814	valid_1's l1: 1.22682
# molecule_atom_index_1_dist_z_mean_diff not added
# [0.06705854041362777] 0.06481939019634651
# Fold 1 started at Tue Jun 18 23:13:58 2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 1.18269	valid_1's l1: 1.23213
# Did not meet early stopping. Best iteration is:
# [500]	training's l1: 1.18269	valid_1's l1: 1.23213
# molecule_type_0_x_1_mean not added
# [0.07484933812737998] 0.06481939019634651
# Fold 1 started at Tue Jun 18 23:16:14 2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 1.18043	valid_1's l1: 1.22882
# Did not meet early stopping. Best iteration is:
# [500]	training's l1: 1.18043	valid_1's l1: 1.22882
# molecule_type_0_dist_z_min_div not added
# [0.07273671502993034] 0.06481939019634651
# Fold 1 started at Tue Jun 18 23:18:30 2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 1.18088	valid_1's l1: 1.22901
# Did not meet early stopping. Best iteration is:
# [500]	training's l1: 1.18088	valid_1's l1: 1.22901
# molecule_atom_1_dist_x_mean_div not added
# [0.0676141694891936] 0.06481939019634651
# Fold 1 started at Tue Jun 18 23:20:47 2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 1.1833	valid_1's l1: 1.23124
# Did not meet early stopping. Best iteration is:
# [500]	training's l1: 1.1833	valid_1's l1: 1.23124
# molecule_atom_1_y_1_std_diff not added
# [0.07313144995497645] 0.06481939019634651
# Fold 1 started at Tue Jun 18 23:23:03 2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 1.1797	valid_1's l1: 1.2279
# Did not meet early stopping. Best iteration is:
# [500]	training's l1: 1.1797	valid_1's l1: 1.2279
# molecule_type_0_dist_z_max_diff not added
# [0.0694781250445819] 0.06481939019634651
# Fold 1 started at Tue Jun 18 23:25:20 2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 1.18268	valid_1's l1: 1.23064
# Did not meet early stopping. Best iteration is:
# [500]	training's l1: 1.18268	valid_1's l1: 1.23064
# molecule_atom_1_dist_x_std not added
# [0.06981480414548447] 0.06481939019634651
# Fold 1 started at Tue Jun 18 23:27:36 2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 1.18371	valid_1's l1: 1.23152
# Did not meet early stopping. Best iteration is:
# [500]	training's l1: 1.18371	valid_1's l1: 1.23152
# molecule_atom_index_0_dist_z_std_div not added
# [0.06982531599315556] 0.06481939019634651
# Fold 1 started at Tue Jun 18 23:29:53 2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 1.18287	valid_1's l1: 1.23126
# Did not meet early stopping. Best iteration is:
# [500]	training's l1: 1.18287	valid_1's l1: 1.23126
# molecule_type_0_dist_x_mean_diff not added
# [0.07372314050740442] 0.06481939019634651
# Fold 1 started at Tue Jun 18 23:32:11 2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 1.18413	valid_1's l1: 1.23309
# Did not meet early stopping. Best iteration is:
# [500]	training's l1: 1.18413	valid_1's l1: 1.23309
# molecule_atom_1_dist_x_std_div not added
# [0.07532904395890332] 0.06481939019634651
# Fold 1 started at Tue Jun 18 23:34:27 2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 1.17751	valid_1's l1: 1.225
# Did not meet early stopping. Best iteration is:
# [500]	training's l1: 1.17751	valid_1's l1: 1.225
# molecule_atom_index_1_x_1_min not added
# [0.06481939019638507] 0.06481939019634651
# Fold 1 started at Tue Jun 18 23:36:45 2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 1.18276	valid_1's l1: 1.23043
# Did not meet early stopping. Best iteration is:
# [500]	training's l1: 1.18276	valid_1's l1: 1.23043
# molecule_type_z_1_min not added
# [0.07611402788665791] 0.06481939019634651
# Fold 1 started at Tue Jun 18 23:39:01 2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 1.18483	valid_1's l1: 1.23252
# Did not meet early stopping. Best iteration is:
# [500]	training's l1: 1.18483	valid_1's l1: 1.23252
# molecule_type_z_1_std_diff not added
# [0.07200244367715714] 0.06481939019634651
# Fold 1 started at Tue Jun 18 23:41:17 2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 1.17702	valid_1's l1: 1.22532
# Did not meet early stopping. Best iteration is:
# [500]	training's l1: 1.17702	valid_1's l1: 1.22532
# molecule_type_x_1_mean not added
# [0.06930327316230586] 0.06481939019634651
# Fold 1 started at Tue Jun 18 23:43:33 2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 1.18305	valid_1's l1: 1.23088
# Did not meet early stopping. Best iteration is:
# [500]	training's l1: 1.18305	valid_1's l1: 1.23088
# molecule_type_z_1_mean_div not added
# [0.07138116492547225] 0.06481939019634651
# Fold 1 started at Tue Jun 18 23:45:47 2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 1.18251	valid_1's l1: 1.23088
# Did not meet early stopping. Best iteration is:
# [500]	training's l1: 1.18251	valid_1's l1: 1.23088
# molecule_atom_1_dist_y_max not added
# [0.07264948407890501] 0.06481939019634651
# Fold 1 started at Tue Jun 18 23:48:02 2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 1.17914	valid_1's l1: 1.22739
# Did not meet early stopping. Best iteration is:
# [500]	training's l1: 1.17914	valid_1's l1: 1.22739
# molecule_type_0_z_1_max_diff not added
# [0.07081245525256016] 0.06481939019634651
# Fold 1 started at Tue Jun 18 23:50:18 2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 1.18239	valid_1's l1: 1.23086
# Did not meet early stopping. Best iteration is:
# [500]	training's l1: 1.18239	valid_1's l1: 1.23086
# molecule_atom_1_dist_x_mean_diff not added
# [0.07360460385854165] 0.06481939019634651
# Fold 1 started at Tue Jun 18 23:52:32 2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 1.1829	valid_1's l1: 1.23149
# Did not meet early stopping. Best iteration is:
# [500]	training's l1: 1.1829	valid_1's l1: 1.23149
# molecule_type_0_dist_z_mean not added
# [0.07043407446245044] 0.06481939019634651
# Fold 1 started at Tue Jun 18 23:54:46 2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 1.18393	valid_1's l1: 1.23198
# Did not meet early stopping. Best iteration is:
# [500]	training's l1: 1
# Did not meet early stopping. Best iteration is:
# [500]	training's l1: 1.17325	valid_1's l1: 1.22165
# molecule_type_dist_y_max_div not added
# [0.05645721123577561] 0.05463905747543836
# Fold 1 started at Wed Jun 19 01:07:12 2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 1.17469	valid_1's l1: 1.22311
# Did not meet early stopping. Best iteration is:
# [500]	training's l1: 1.17469	valid_1's l1: 1.22311
# molecule_type_x_1_std_div not added
# [0.059673979332532295] 0.05463905747543836
# Fold 1 started at Wed Jun 19 01:09:38 2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 1.17497	valid_1's l1: 1.22287
# Did not meet early stopping. Best iteration is:
# [500]	training's l1: 1.17497	valid_1's l1: 1.22287
# molecule_atom_index_1_x_1_std not added
# [0.05463906326726479] 0.05463905747543836
# Fold 1 started at Wed Jun 19 01:12:02 2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 1.17532	valid_1's l1: 1.22359
# Did not meet early stopping. Best iteration is:
# [500]	training's l1: 1.17532	valid_1's l1: 1.22359
# molecule_type_x_1_std_diff not added
# [0.054707148463394445] 0.05463905747543836
# Fold 1 started at Wed Jun 19 01:14:29 2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 1.17505	valid_1's l1: 1.22311
# Did not meet early stopping. Best iteration is:
# [500]	training's l1: 1.17505	valid_1's l1: 1.22311
# molecule_type_dist_y_max_diff not added
# [0.06053472493411315] 0.05463905747543836
# Fold 1 started at Wed Jun 19 01:16:55 2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 1.1722	valid_1's l1: 1.22164
# Did not meet early stopping. Best iteration is:
# [500]	training's l1: 1.1722	valid_1's l1: 1.22164
# molecule_type_0_dist_std_div not added
# [0.05668353060094366] 0.05463905747543836
# Fold 1 started at Wed Jun 19 01:19:20 2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 1.17497	valid_1's l1: 1.22287
# Did not meet early stopping. Best iteration is:
# [500]	training's l1: 1.17497	valid_1's l1: 1.22287
# molecule_atom_index_1_z_1_max_diff not added
# [0.05463906326731902] 0.05463905747543836
# Fold 1 started at Wed Jun 19 01:21:48 2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 1.1709	valid_1's l1: 1.21941
# Did not meet early stopping. Best iteration is:
# [500]	training's l1: 1.1709	valid_1's l1: 1.21941
# molecule_type_0_dist_min_div added
# [0.05289871685844904] 0.05289871685844904
# Fold 1 started at Wed Jun 19 01:24:21 2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 1.17422	valid_1's l1: 1.22283
# Did not meet early stopping. Best iteration is:
# [500]	training's l1: 1.17422	valid_1's l1: 1.22283
# molecule_type_dist_y_mean_div not added
# [0.056745599675009535] 0.05289871685844904
# Fold 1 started at Wed Jun 19 01:26:48 2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 1.1747	valid_1's l1: 1.22269
# Did not meet early stopping. Best iteration is:
# [500]	training's l1: 1.1747	valid_1's l1: 1.22269
# molecule_type_0_dist_z_mean_div not added
# [0.059420770917080215] 0.05289871685844904
# Fold 1 started at Wed Jun 19 01:29:16 2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 1.17191	valid_1's l1: 1.22126
# Did not meet early stopping. Best iteration is:
# [500]	training's l1: 1.17191	valid_1's l1: 1.22126
# molecule_type_dist_max not added
# [0.0546615524894248] 0.05289871685844904
# Fold 1 started at Wed Jun 19 01:31:43 2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 1.17254	valid_1's l1: 1.22187
# Did not meet early stopping. Best iteration is:
# [500]	training's l1: 1.17254	valid_1's l1: 1.22187
# molecule_atom_1_dist_std not added
# [0.05650082607968868] 0.05289871685844904
# Fold 1 started at Wed Jun 19 01:34:10 2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 1.17313	valid_1's l1: 1.22181
# Did not meet early stopping. Best iteration is:
# [500]	training's l1: 1.17313	valid_1's l1: 1.22181
# molecule_atom_1_dist_y_std_diff not added
# [0.05525995437853865] 0.05289871685844904
# Fold 1 started at Wed Jun 19 01:36:35 2019
# Training until validation scores don't improve for 200 rounds.
# ...
# [500]	training's l1: 1.12119	valid_1's l1: 1.17009
# molecule_atom_1_y_1_max_diff not added
# [0.01804534082353] 0.008707949428786728
# Fold 1 started at Wed Jun 19 09:35:13 2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 1.12071	valid_1's l1: 1.1686
# Did not meet early stopping. Best iteration is:
# [500]	training's l1: 1.12071	valid_1's l1: 1.1686
# molecule_atom_index_1_y_1_max not added
# [0.008714264302868459] 0.008707949428786728
# Fold 1 started at Wed Jun 19 09:38:03 2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 1
# Did not meet early stopping. Best iteration is:
# [500]	training's l1: 1.12294	valid_1's l1: 1.17149
# molecule_type_dist_x_min not added
# [0.014450245802987934] 0.005501861793747752
# Fold 1 started at Wed Jun 19 11:07:19 2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 1.1219	valid_1's l1: 1.17018
# Did not meet early stopping. Best iteration is:
# [500]	training's l1: 1.1219	valid_1's l1: 1.17018
# molecule_type_0_x_1_max_div not added
# [0.017997623812840167] 0.005501861793747752
# Fold 1 started at Wed Jun 19 11:10:11 2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 1.12447	valid_1's l1: 1.17309
# Did not meet early stopping. Best iteration is:
# [500]	training's l1: 1.12447	valid_1's l1: 1.17309
# molecule_atom_index_0_dist_z_max not added
# [0.01400087715009471] 0.005501861793747752
# Fold 1 started at Wed Jun 19 11:13:03 2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 1.11788	valid_1's l1: 1.16563
# Did not meet early stopping. Best iteration is:
# [500]	training's l1: 1.11788	valid_1's l1: 1.16563
# molecule_type_dist_x_std_diff added
# [0.0047639545033795125] 0.0047639545033795125
# Fold 1 started at Wed Jun 19 11:15:56 2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 1.11788	valid_1's l1: 1.16563
# Did not meet early stopping. Best iteration is:
# [500]	training's l1: 1.11788	valid_1's l1: 1.16563
# molecule_atom_index_1_z_1_min_diff not added
# [0.004763954503396915] 0.0047639545033795125
# Fold 1 started at Wed Jun 19 11:18:50 2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 1.12061	valid_1's l1: 1.16908
# Did not meet early stopping. Best iteration is:
# [500]	training's l1: 1.12061	valid_1's l1: 1.16908
# molecule_type_0_dist_y_max_diff not added
# [0.014093530672287413] 0.0047639545033795125
# Fold 1 started at Wed Jun 19 11:21:41 2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 1.12262	valid_1's l1: 1.17084
# Did not meet early stopping. Best iteration is:
# [500]	training's l1: 1.12262	valid_1's l1: 1.17084
# molecule_atom_1_z_1_min_div not added
# [0.01802537954075232] 0.0047639545033795125
# Fold 1 started at Wed Jun 19 11:24:34 2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 1.12081	valid_1's l1: 1.16881
# Did not meet early stopping. Best iteration is:
# [500]	training's l1: 1.12081	valid_1's l1: 1.16881
# molecule_type_0_dist_z_max_div not added
# [0.014715616433037149] 0.0047639545033795125
# Fold 1 started at Wed Jun 19 11:27:27 2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 1.12362	valid_1's l1: 1.172
# Did not meet early stopping. Best iteration is:
# [500]	training's l1: 1.12362	valid_1's l1: 1.172
# molecule_type_dist_y_std not added
# [0.014852519702221234] 0.0047639545033795125
# Fold 1 started at Wed Jun 19 11:30:19 2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 1.1217	valid_1's l1: 1.16956
# Did not meet early stopping. Best iteration is:
# [500]	training's l1: 1.1217	valid_1's l1: 1.16956
# molecule_atom_1_dist_z_mean not added
# [0.012782619420032192] 0.0047639545033795125
# Fold 1 started at Wed Jun 19 11:33:10 2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 1.12292	valid_1's l1: 1.17119
# Did not meet early stopping. Best iteration is:
# [500]	training's l1: 1.12292	valid_1's l1: 1.17119
# molecule_type_0_x_1_mean_diff not added
# [0.016808108666651174] 0.0047639545033795125
# Fold 1 started at Wed Jun 19 11:36:04 2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 1.11816	valid_1's l1: 1.16569
# Did not meet early stopping. Best iteration is:
# [500]	training's l1: 1.11816	valid_1's l1: 1.16569
# molecule_atom_1_dist_z_min not added
# [0.01092650726572069] 0.0047639545033795125
# Fold 1 started at Wed Jun 19 11:38:56 2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 1.11696	valid_1's l1: 1.16365
# Did not meet early stopping. Best iteration is:
# [500]	training's l1: 1.11696	valid_1's l1: 1.16365
# molecule_type_y_1_std not added
# [0.009372960682969798] 0.0047639545033795125
# Fold 1 started at Wed Jun 19 11:41:51 2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 1.12296	valid_1's l1: 1.17084
# Did not meet early stopping. Best iteration is:
# [500]	training's l1: 1.12296	valid_1's l1: 1.17084
# molecule_atom_index_1_dist_x_min not added
# [0.013234895046380743] 0.0047639545033795125
# Fold 1 started at Wed Jun 19 11:44:43 2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 1.11955	valid_1's l1: 1.16835
# Did not meet early stopping. Best iteration is:
# [500]	training's l1: 1.11955	valid_1's l1: 1.16835
# molecule_type_y_1_mean not added
# [0.011711727515450313] 0.0047639545033795125
# Fold 1 started at Wed Jun 19 11:47:37 2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 1.12269	valid_1's l1: 1.17115
# Did not meet early stopping. Best iteration is:
# [500]	training's l1: 1.12269	valid_1's l1: 1.17115
# molecule_atom_1_dist_y_mean not added
# [0.014421802757490707] 0.0047639545033795125

# %%
good_columns
# Out:
# ['molecule_atom_index_0_dist_min',
#  'molecule_atom_index_0_dist_max',
#  'atom_index_0',
#  'atom_index_1',
#  'type',
#  'x_0',
#  'y_0',
#  'z_0',
#  'atom_1',
#  'x_1',
#  'y_1',
#  'z_1',
#  'dist',
#  'dist_y',
#  'r',
#  'molecule_couples',
#  'molecule_dist_mean',
#  'molecule_dist_min',
#  'molecule_dist_max',
#  'molecule_dist_std',
#  'atom_0_couples_count',
#  'atom_1_couples_count',
#  'type_1_couples_count',
#  'molecule_dyz_mean',
#  'molecule_dxz_mean',
#  'molecule_atom_index_0_x_1_mean',
#  'molecule_atom_index_0_x_1_mean_diff',
#  'molecule_atom_index_0_x_1_max_diff',
#  'molecule_atom_index_0_y_1_mean',
#  'molecule_atom_index_0_y_1_mean_diff',
#  'molecule_atom_index_0_y_1_max',
#  'molecule_atom_index_0_y_1_max_diff',
#  'molecule_atom_index_0_y_1_std',
#  'molecule_atom_index_0_y_1_std_diff',
#  'molecule_atom_index_0_y_1_min_diff',
#  'molecule_atom_index_0_z_1_mean',
#  'molecule_atom_index_0_z_1_mean_diff',
#  'molecule_atom_index_0_z_1_std',
#  'molecule_atom_index_0_z_1_std_diff',
#  'molecule_atom_index_0_z_1_std_div',
#  'molecule_atom_index_0_dist_mean',
#  'molecule_atom_index_0_dist_mean_diff',
#  'molecule_atom_index_0_dist_max_div',
#  'molecule_atom_index_0_dist_std',
#  'molecule_atom_index_0_dist_std_diff',
#  'molecule_atom_index_0_dist_std_div',
#  'molecule_atom_index_0_dist_min_diff',
#  'x1',
#  'molecule_atom_index_0_dist_y_std_div',
#  'molecule_type_0_dist_x_std_div',
#  'molecule_atom_index_1_z_1_min_div',
#  'molecule_atom_index_1_dist_max_diff',
#  'molecule_type_0_z_1_mean',
#  'molecule_atom_index_1_y_1_min_div',
#  'molecule_atom_index_1_dist_z_std',
#  'molecule_atom_index_1_dist_mean_diff',
#  'molecule_atom_1_x_1_max_diff',
#  'molecule_atom_index_0_dist_y_mean',
#  'molecule_atom_1_dist_z_max_div',
#  'molecule_atom_1_dist_min',
#  'molecule_atom_index_1_x_1_min_div',
#  'molecule_atom_index_1_y_1_max_diff',
#  'molecule_type_0_dist_max_diff',
#  'molecule_atom_1_dist_mean_div',
#  'molecule_atom_index_1_x_1_max_div',
#  'molecule_type_dist_min_div',
#  'molecule_type_0_dist_min_div',
#  'molecule_atom_index_0_dist_z_min_div',
#  'molecule_atom_1_dist_mean',
#  'molecule_atom_index_1_z_1_mean',
#  'molecule_atom_index_1_dist_std_diff',
#  'molecule_type_y_1_max',
#  'molecule_type_0_dist_x_max_div',
#  'molecule_atom_1_dist_y_std',
#  'molecule_type_0_dist_x_std',
#  'molecule_atom_index_1_z_1_std_diff',
#  'molecule_atom_index_1_z_1_max_div',
#  'molecule_atom_index_1_dist_min',
#  'molecule_atom_index_1_dist_y_min',
#  'molecule_atom_index_1_z_1_mean_div',
#  'molecule_type_y_1_min_diff',
#  'molecule_type_0_dist_max_div',
#  'molecule_atom_1_dist_min_diff',
#  'molecule_atom_index_1_dist_std',
#  'atom_0',
#  'molecule_type_dist_x_std_diff']

# %%
X = train[good_columns].copy()
y = train['scalar_coupling_constant']
X_test = test[good_columns].copy()
params = {'num_leaves': 128,
          'min_child_samples': 79,
          'objective': 'regression',
          'max_depth': 9,
          'learning_rate': 0.2,
          "boosting_type": "gbdt",
          "subsample_freq": 1,
          "subsample": 0.9,
          "bagging_seed": 11,
          "metric": 'mae',
          "verbosity": -1,
          'reg_alpha': 0.1,
          'reg_lambda': 0.3,
          'colsample_bytree': 1.0
         }
result_dict_lgb = train_model_regression(X=X, X_test=X_test, y=y, params=params, folds=folds, 
                                         model_type='lgb', eval_metric='group_mae', 
                                         plot_feature_importance=False,
                                         verbose=500, early_stopping_rounds=200, n_estimators=5000)
# Out:
# Fold 1 started at Wed Jun 19 13:41:13 2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 1.11788	valid_1's l1: 1.16563
# [1000]	training's l1: 0.986793	valid_1's l1: 1.0706
# [1500]	training's l1: 0.903386	valid_1's l1: 1.01763
# [2000]	training's l1: 0.843713	valid_1's l1: 0.985154
# [2500]	training's l1: 0.795028	valid_1's l1: 0.960662
# [3000]	training's l1: 0.753609	valid_1's l1: 0.941262
# [3500]	training's l1: 0.717692	valid_1's l1: 0.925874
# [4000]	training's l1: 0.686388	valid_1's l1: 0.913928
# [4500]	training's l1: 0.658277	valid_1's l1: 0.904057
# [5000]	training's l1: 0.632336	valid_1's l1: 0.895117
# Did not meet early stopping. Best iteration is:
# [5000]	training's l1: 0.632336	valid_1's l1: 0.895117
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-285-9713469a35f6> in <module>()
#      20                                          model_type='lgb', eval_metric='group_mae',
#      21                                          plot_feature_importance=False,
# ---> 22                                          verbose=500, early_stopping_rounds=200, n_estimators=5000)
#
# ~/lal/Kaggle/kagglepmp/scripts_nbs/artgor_utils.py in train_model_regression(X, X_test, y, params, folds, model_type, eval_metric, columns, plot_feature_importance, model, verbose, early_stopping_rounds, n_estimators)
#     226
#     227             y_pred_valid = model.predict(X_valid)
# --> 228             y_pred = model.predict(X_test, num_iteration=model.best_iteration_)
#     229
#     230         if model_type == 'xgb':
#
# ~/anaconda3/envs/pmp/lib/python3.6/site-packages/lightgbm/sklearn.py in predict(self, X, raw_score, num_iteration, pred_leaf, pred_contrib, **kwargs)
#     605                              % (self._n_features, n_features))
#     606         return self.booster_.predict(X, raw_score=raw_score, num_iteration=num_iteration,
# --> 607                                      pred_leaf=pred_leaf, pred_contrib=pred_contrib, **kwargs)
#     608
#     609     @property
#
# ~/anaconda3/envs/pmp/lib/python3.6/site-packages/lightgbm/basic.py in predict(self, data, num_iteration, raw_score, pred_leaf, pred_contrib, data_has_header, is_reshape, **kwargs)
#    2201         return predictor.predict(data, num_iteration,
#    2202                                  raw_score, pred_leaf, pred_contrib,
# -> 2203                                  data_has_header, is_reshape)
#    2204
#    2205     def refit(self, data, label, decay_rate=0.9, **kwargs):
#
# ~/anaconda3/envs/pmp/lib/python3.6/site-packages/lightgbm/basic.py in predict(self, data, num_iteration, raw_score, pred_leaf, pred_contrib, data_has_header, is_reshape)
#     465             preds, nrow = self.__pred_for_csc(data, num_iteration, predict_type)
#     466         elif isinstance(data, np.ndarray):
# --> 467             preds, nrow = self.__pred_for_np2d(data, num_iteration, predict_type)
#     468         elif isinstance(data, list):
#     469             try:
#
# ~/anaconda3/envs/pmp/lib/python3.6/site-packages/lightgbm/basic.py in __pred_for_np2d(self, mat, num_iteration, predict_type)
#     554             return preds, nrow
#     555         else:
# --> 556             return inner_predict(mat, num_iteration, predict_type)
#     557
#     558     def __pred_for_csr(self, csr, num_iteration, predict_type):
#
# ~/anaconda3/envs/pmp/lib/python3.6/site-packages/lightgbm/basic.py in inner_predict(mat, num_iteration, predict_type, preds)
#     536                 c_str(self.pred_parameter),
#     537                 ctypes.byref(out_num_preds),
# --> 538                 preds.ctypes.data_as(ctypes.POINTER(ctypes.c_double))))
#     539             if n_preds != out_num_preds.value:
#     540                 raise ValueError("Wrong length for predict results")
#
# KeyboardInterrupt:

# %%
remaining_cols = list(train.columns)
good_columns = [
    'molecule_atom_index_0_dist_min',
]
min_score = 24.50654

# %%
gc.collect()
# Out:
# 987

# %%
for col in tqdm_notebook(remaining_cols):
    if col in skip_cols:
        continue
    if col in good_columns:
        continue
    good_cols = good_columns.copy()
    good_cols.append(col)
    X = train[good_cols].copy()
    y = train['scalar_coupling_constant']
    X_test = test[good_cols].copy()
    
    params = {'num_leaves': 128,
          'min_child_samples': 79,
          'objective': 'regression',
          'max_depth': 9,
          'learning_rate': 0.2,
          "boosting_type": "gbdt",
          "subsample_freq": 1,
          "subsample": 0.9,
          "bagging_seed": 11,
          "metric": 'mae',
          "verbosity": -1,
          'reg_alpha': 0.1,
          'reg_lambda': 0.3,
          'colsample_bytree': 1.0
         }
    result_dict_lgb = train_model_regression2(X=X, X_test=X_test, y=y, params=params, folds=folds, 
                                             model_type='lgb', eval_metric='mae', 
                                             plot_feature_importance=False,
                                             verbose=500, early_stopping_rounds=200, n_estimators=500)

    curr_score = result_dict_lgb['scores'][0]
    if curr_score < min_score:
        good_columns.append(col)
        min_score = curr_score
        print('{} added ****'.format(col))
    else:
        print('{} not added'.format(col))
    print(result_dict_lgb['scores'], min_score)
    del X, X_test
    gc.collect()
#     break
# Out:
# HBox(children=(IntProgress(value=0, max=487), HTML(value='')))
# Fold 1 started at Wed Jun 19 14:11:49 2019
# Training until validation scores don't improve for 200 rounds.
# Early stopping, best iteration is:
# [91]	training's l1: 24.5084	valid_1's l1: 24.4775
# atom_index_0 added ****
# [24.477471581729546] 24.477471581729546
# Fold 1 started at Wed Jun 19 14:12:17 2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 17.65	valid_1's l1: 17.6576
# Did not meet early stopping. Best iteration is:
# [500]	training's l1: 17.65	valid_1's l1: 17.6576
# atom_index_1 added ****
# [17.657574478021278] 17.657574478021278
# Fold 1 started at Wed Jun 19 14:13:15 2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 2.5552	valid_1's l1: 2.55812
# Did not meet early stopping. Best iteration is:
# [500]	training's l1: 2.5552	valid_1's l1: 2.55812
# type added ****
# [2.558117175002845] 2.558117175002845
# Fold 1 started at Wed Jun 19 14:14:15 2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 2.5552	valid_1's l1: 2.55812
# Did not meet early stopping. Best iteration is:
# [500]	training's l1:
# Did not meet early stopping. Best iteration is:
# [500]	training's l1: 1.11642	valid_1's l1: 1.16366
# molecule_type_0_dist_y_mean_div not added
# [1.1636648703048595] 1.158603276957387
# Fold 1 started at Thu Jun 20 07:44:34 2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 1.11936	valid_1's l1: 1.16661
# Did not meet early stopping. Best iteration is:
# [500]	training's l1: 1.11936	valid_1's l1: 1.16661
# molecule_type_0_dist_y_max not added
# [1.1666137099821279] 1.158603276957387
# Fold 1 started at Thu Jun 20 07:47:16 2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 1.11849	valid_1's l1: 1.16554
# Did not meet early stopping. Best iteration is:
# [500]	training's l1: 1.11849	valid_1's l1: 1.16554
# molecule_type_0_dist_y_max_diff not added
# [1.1655355697293441] 1.158603276957387
# Fold 1 started at Thu Jun 20 07:49:58 2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 1.11881	valid_1's l1: 1.16605
# Did not meet early stopping. Best iteration is:
# [500]	training's l1: 1.11881	valid_1's l1: 1.16605
# molecule_type_0_dist_y_max_div not added
# [1.1660489122039195] 1.158603276957387
# Fold 1 started at Thu Jun 20 07:52:39 2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 1.11733	valid_1's l1: 1.16512
# Did not meet early stopping. Best iteration is:
# [500]	training's l1: 1.11733	valid_1's l1: 1.16512
# molecule_type_0_dist_y_std not added
# [1.165117148441951] 1.158603276957387
# Fold 1 started at Thu Jun 20 07:55:21 2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 1.11556	valid_1's l1: 1.16267
# Did not meet early stopping. Best iteration is:
# [500]	training's l1: 1.11556	valid_1's l1: 1.16267
# molecule_type_0_dist_y_std_diff not added
# [1.1626695393398168] 1.158603276957387
# Fold 1 started at Thu Jun 20 07:58:03 2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 1.11638	valid_1's l1: 1.16305
# Did not meet early stopping. Best iteration is:
# [500]	training's l1: 1.11638	valid_1's l1: 1.16305
# molecule_type_0_dist_y_std_div not added
# [1.1632292905980064] 1.158603276957387
# Fold 1 started at Thu Jun 20 08:00:44 2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 1.11851	valid_1's l1: 1.16643
# Did not meet early stopping. Best iteration is:
# [500]	training's l1: 1.11851	valid_1's l1: 1.16643
# molecule_type_0_dist_y_min not added
# [1.1664289156087573] 1.158603276957387
# Fold 1 started at Thu Jun 20 08:03:25 2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 1.11734	valid_1's l1: 1.16415
# Did not meet early stopping. Best iteration is:
# [500]	training's l1: 1.11734	valid_1's l1: 1.16415
# molecule_type_0_dist_y_min_diff not added
# [1.1641516235553597] 1.158603276957387
# Fold 1 started at Thu Jun 20 08:06:05 2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 1.11908	valid_1's l1: 1.16646
# Did not meet early stopping. Best iteration is:
# [500]	training's l1: 1.11908	valid_1's l1: 1.16646
# molecule_type_0_dist_y_min_div not added
# [1.1664579278125078] 1.158603276957387
# Fold 1 started at Thu Jun 20 08:08:46 2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 1.11828	valid_1's l1: 1.16476
# Did not meet early stopping. Best iteration is:
# [500]	training's l1: 1.11828	valid_1's l1: 1.16476
# molecule_type_0_dist_z_mean not added
# [1.1647636889573216] 1.158603276957387
# Fold 1 started at Thu Jun 20 08:11:28 2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 1.11585	valid_1's l1: 1.16287
# Did not meet early stopping. Best iteration is:
# [500]	training's l1: 1.11585	valid_1's l1: 1.16287
# molecule_type_0_dist_z_mean_diff not added
# [1.1628681617252332] 1.158603276957387
# Fold 1 started at Thu Jun 20 08:14:10 2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 1.11849	valid_1's l1: 1.16474
# Did not meet early stopping. Best iteration is:
# [500]	training's l1: 1.11849	valid_1's l1: 1.16474
# molecule_type_0_dist_z_mean_div not added
# [1.1647415217593844] 1.158603276957387
# Fold 1 started at Thu Jun 20 08:16:52 2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 1.11698	valid_1's l1: 1.16455
# Did not meet early stopping. Best iteration is:
# [500]	training's l1: 1.11698	valid_1's l1: 1.16455
# molecule_type_0_dist_z_max not added
# [1.164547752582332] 1.158603276957387
# Fold 1 started at Thu Jun 20 08:19:34 2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 1.11574	valid_1's l1: 1.16304
# Did not meet early stopping. Best iteration is:
# [500]	training's l1: 1.11574	valid_1's l1: 1.16304
# molecule_type_0_dist_z_max_diff not added
# [1.1630429725594738] 1.158603276957387
# Fold 1 started at Thu Jun 20 08:22:17 2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 1.11626	valid_1's l1: 1.16302
# Did not meet early stopping. Best iteration is:
# [500]	training's l1: 1.11626	valid_1's l1: 1.16302
# molecule_type_0_dist_z_max_div not added
# [1.1630210082485257] 1.158603276957387
# Fold 1 started at Thu Jun 20 08:24:56 2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 1.11851	valid_1's l1: 1.1663
# Did not meet early stopping. Best iteration is:
# [500]	training's l1: 1.11851	valid_1's l1: 1.1663
# molecule_type_0_dist_z_std not added
# [1.166299762813187] 1.158603276957387
# Fold 1 started at Thu Jun 20 08:27:38 2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 1.12209	valid_1's l1: 1.16935
# Did not meet early stopping. Best iteration is:
# [500]	training's l1: 1.12209	valid_1's l1: 1.16935
# molecule_type_0_dist_z_std_diff not added
# [1.1693458058047839] 1.158603276957387
# Fold 1 started at Thu Jun 20 08:30:17 2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 1.11876	valid_1's l1: 1.1658
# Did not meet early stopping. Best iteration is:
# [500]	training's l1: 1.11876	valid_1's l1: 1.1658
# molecule_type_0_dist_z_std_div not added
# [1.1658063423568061] 1.158603276957387
# Fold 1 started at Thu Jun 20 08:33:00 2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 1.1189	valid_1's l1: 1.16648
# Did not meet early stopping. Best iteration is:
# [500]	training's l1: 1.1189	valid_1's l1: 1.16648
# molecule_type_0_dist_z_min not added
# [1.1664835422767206] 1.158603276957387
# Fold 1 started at Thu Jun 20 08:35:39 2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 1.11963	valid_1's l1: 1.16685
# Did not meet early stopping. Best iteration is:
# [500]	training's l1: 1.11963	valid_1's l1: 1.16685
# molecule_type_0_dist_z_min_diff not added
# [1.1668479997550185] 1.158603276957387
# Fold 1 started at Thu Jun 20 08:38:21 2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 1.11991	valid_1's l1: 1.16687
# Did not meet early stopping. Best iteration is:
# [500]	training's l1: 1.11991	valid_1's l1: 1.16687
# molecule_type_0_dist_z_min_div not added
# [1.166873345539341] 1.158603276957387

# %%
good_columns
# Out:
# ['molecule_atom_index_0_dist_min',
#  'atom_index_0',
#  'atom_index_1',
#  'type',
#  'atom_0',
#  'x_0',
#  'y_0',
#  'z_0',
#  'atom_1',
#  'x_1',
#  'y_1',
#  'z_1',
#  'dist',
#  'dx',
#  'dy',
#  'r',
#  'x2',
#  'molecule_couples',
#  'molecule_dist_mean',
#  'molecule_dist_min',
#  'molecule_dist_max',
#  'molecule_dist_std',
#  'atom_0_couples_count',
#  'atom_1_couples_count',
#  'type_1_couples_count',
#  'molecule_dxy_mean',
#  'molecule_dxy_std',
#  'molecule_dxz_std',
#  'molecule_dyz_mean',
#  'molecule_dyz_std',
#  'molecule_atom_index_1_count',
#  'molecule_atom_index_0_x_1_mean',
#  'molecule_atom_index_0_x_1_mean_diff',
#  'molecule_atom_index_0_x_1_mean_div',
#  'molecule_atom_index_0_x_1_std',
#  'molecule_atom_index_0_x_1_std_diff',
#  'molecule_atom_index_0_x_1_min',
#  'molecule_atom_index_0_y_1_mean',
#  'molecule_atom_index_0_y_1_mean_diff',
#  'molecule_atom_index_0_y_1_max',
#  'molecule_atom_index_0_y_1_max_diff',
#  'molecule_atom_index_0_y_1_max_div',
#  'molecule_atom_index_0_y_1_std',
#  'molecule_atom_index_0_y_1_std_diff',
#  'molecule_atom_index_0_z_1_mean',
#  'molecule_atom_index_0_z_1_mean_diff',
#  'molecule_atom_index_0_z_1_max_diff',
#  'molecule_atom_index_0_z_1_max_div',
#  'molecule_atom_index_0_z_1_std',
#  'molecule_atom_index_0_z_1_min_div',
#  'molecule_atom_index_0_dist_mean',
#  'molecule_atom_index_0_dist_max',
#  'molecule_atom_index_0_dist_max_diff',
#  'molecule_atom_index_0_dist_max_div',
#  'molecule_atom_index_0_dist_std',
#  'molecule_atom_index_0_dist_std_diff',
#  'molecule_atom_index_0_dist_std_div',
#  'molecule_atom_index_0_dist_min_diff',
#  'molecule_atom_index_0_dist_x_mean_diff',
#  'molecule_atom_index_1_dist_mean',
#  'molecule_atom_index_1_dist_mean_diff',
#  'molecule_atom_index_1_dist_mean_div',
#  'molecule_atom_index_1_dist_max',
#  'molecule_atom_index_1_dist_max_diff',
#  'molecule_atom_index_1_dist_max_div',
#  'molecule_atom_index_1_dist_std',
#  'molecule_atom_index_1_dist_std_diff',
#  'molecule_atom_index_1_dist_std_div',
#  'molecule_atom_index_1_dist_min',
#  'molecule_atom_index_1_dist_min_diff',
#  'molecule_atom_index_1_dist_min_div',
#  'molecule_atom_index_1_dist_x_mean',
#  'molecule_atom_index_1_dist_x_max_div',
#  'molecule_atom_index_1_dist_z_min_div',
#  'molecule_type_y_1_std_diff',
#  'molecule_type_z_1_std']

# %%
X = train[good_columns].copy()
y = train['scalar_coupling_constant']
X_test = test[good_columns].copy()
params = {'num_leaves': 128,
          'min_child_samples': 79,
          'objective': 'regression',
          'max_depth': 9,
          'learning_rate': 0.2,
          "boosting_type": "gbdt",
          "subsample_freq": 1,
          "subsample": 0.9,
          "bagging_seed": 11,
          "metric": 'mae',
          "verbosity": -1,
          'reg_alpha': 0.1,
          'reg_lambda': 0.3,
          'colsample_bytree': 1.0
         }
result_dict_lgb = train_model_regression(X=X, X_test=X_test, y=y, params=params, folds=folds, model_type='lgb', eval_metric='group_mae', plot_feature_importance=True,
                                                      verbose=500, early_stopping_rounds=200, n_estimators=5000)
# Out:
# Fold 1 started at Thu Jun 20 11:29:50 2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 1.11133	valid_1's l1: 1.1586
# [1000]	training's l1: 0.98473	valid_1's l1: 1.06699
# [1500]	training's l1: 0.903961	valid_1's l1: 1.01586
# [2000]	training's l1: 0.844256	valid_1's l1: 0.982664
# [2500]	training's l1: 0.796878	valid_1's l1: 0.959015
# [3000]	training's l1: 0.756137	valid_1's l1: 0.939999
# [3500]	training's l1: 0.720506	valid_1's l1: 0.924476
# [4000]	training's l1: 0.68955	valid_1's l1: 0.912185
# [4500]	training's l1: 0.661298	valid_1's l1: 0.901747
# [5000]	training's l1: 0.635542	valid_1's l1: 0.892508
# Did not meet early stopping. Best iteration is:
# [5000]	training's l1: 0.635542	valid_1's l1: 0.892508
# Fold 2 started at Thu Jun 20 11:52:28 2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 1.11814	valid_1's l1: 1.1653
# [1000]	training's l1: 0.985897	valid_1's l1: 1.06818
# [1500]	training's l1: 0.905068	valid_1's l1: 1.01721
# [2000]	training's l1: 0.844802	valid_1's l1: 0.983439
# [2500]	training's l1: 0.795897	valid_1's l1: 0.958083
# [3000]	training's l1: 0.754963	valid_1's l1: 0.9387
# [3500]	training's l1: 0.720199	valid_1's l1: 0.924372
# [4000]	training's l1: 0.688746	valid_1's l1: 0.911716
# [4500]	training's l1: 0.660548	valid_1's l1: 0.901077
# [5000]	training's l1: 0.635076	valid_1's l1: 0.892329
# Did not meet early stopping. Best iteration is:
# [5000]	training's l1: 0.635076	valid_1's l1: 0.892329
# Fold 3 started at Thu Jun 20 12:14:38 2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 1.11906	valid_1's l1: 1.1683
# [1000]	training's l1: 0.989473	valid_1's l1: 1.0741
# [1500]	training's l1: 0.907606	valid_1's l1: 1.0225
# [2000]	training's l1: 0.846441	valid_1's l1: 0.98772
# [2500]	training's l1: 0.798481	valid_1's l1: 0.963038
# [3000]	training's l1: 0.757637	valid_1's l1: 0.943959
# [3500]	training's l1: 0.72198	valid_1's l1: 0.928673
# [4000]	training's l1: 0.690572	valid_1's l1: 0.916
# [4500]	training's l1: 0.662313	valid_1's l1: 0.905277
# [5000]	training's l1: 0.636922	valid_1's l1: 0.896777
# Did not meet early stopping. Best iteration is:
# [5000]	training's l1: 0.636922	valid_1's l1: 0.896777
# Fold 4 started at Thu Jun 20 12:36:37 2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 1.11905	valid_1's l1: 1.16686
# [1000]	training's l1: 0.985067	valid_1's l1: 1.06811
# [1500]	training's l1: 0.904509	valid_1's l1: 1.01815
# [2000]	training's l1: 0.845172	valid_1's l1: 0.98518
# [2500]	training's l1: 0.797241	valid_1's l1: 0.961088
# [3000]	training's l1: 0.75565	valid_1's l1: 0.941167
# [3500]	training's l1: 0.721055	valid_1's l1: 0.926712
# [4000]	training's l1: 0.689907	valid_1's l1: 0.91435
# [4500]	training's l1: 0.661252	valid_1's l1: 0.903252
# [5000]	training's l1: 0.635505	valid_1's l1: 0.894387
# Did not meet early stopping. Best iteration is:
# [5000]	training's l1: 0.635505	valid_1's l1: 0.894387
# Fold 5 started at Thu Jun 20 12:58:40 2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 1.11924	valid_1's l1: 1.1715
# [1000]	training's l1: 0.988139	valid_1's l1: 1.075
# [1500]	training's l1: 0.905909	valid_1's l1: 1.02176
# [2000]	training's l1: 0.846267	valid_1's l1: 0.988493
# [2500]	training's l1: 0.798617	valid_1's l1: 0.964817
# [3000]	training's l1: 0.757615	valid_1's l1: 0.94554
# [3500]	training's l1: 0.722312	valid_1's l1: 0.930483
# [4000]	training's l1: 0.691177	valid_1's l1: 0.917966
# [4500]	training's l1: 0.662805	valid_1's l1: 0.907096
# [5000]	training's l1: 0.637135	valid_1's l1: 0.897982
# Did not meet early stopping. Best iteration is:
# [5000]	training's l1: 0.637135	valid_1's l1: 0.897982
# CV mean score: -0.2381, std: 0.0023.

# %%
# Out:
# {'H': 0.43, 'C': 0.8200000000000001, 'N': 0.8, 'O': 0.78, 'F': 0.76}
# HBox(children=(IntProgress(value=0, max=2358657), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=2358657), HTML(value='')))
#       molecule_name  atom_index atom             x             y  \
# 0  dsgdb9nsd_000001           0    C -0.0126981359  1.0858041580
# 1  dsgdb9nsd_000001           1    H  0.0021504160 -0.0060313176
# 2  dsgdb9nsd_000001           2    H  1.0117308430  1.4637511620
# 3  dsgdb9nsd_000001           3    H -0.5408150690  1.4475266140
# 4  dsgdb9nsd_000001           4    H -0.5238136345  1.4379326440
#
#               z    EN   rad
# 0  0.0080009958  2.55  0.82
# 1  0.0019761204  2.20  0.43
# 2  0.0002765748  2.20  0.43
# 3 -0.8766437152  2.20  0.43
# 4  0.9063972942  2.20  0.43

# %%
# Out:
# Calculating the bonds
# HBox(children=(IntProgress(value=0, max=27), HTML(value='')))
# Counting and condensing bonds
# HBox(children=(IntProgress(value=0, max=2358657), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=2358657), HTML(value='')))
#        molecule_name  atom_index atom             x             y  \
# 0   dsgdb9nsd_000001           0    C -0.0126981359  1.0858041580
# 1   dsgdb9nsd_000001           1    H  0.0021504160 -0.0060313176
# 2   dsgdb9nsd_000001           2    H  1.0117308430  1.4637511620
# 3   dsgdb9nsd_000001           3    H -0.5408150690  1.4475266140
# 4   dsgdb9nsd_000001           4    H -0.5238136345  1.4379326440
# 5   dsgdb9nsd_000002           0    N -0.0404260543  1.0241077530
# 6   dsgdb9nsd_000002           1    H  0.0172574639  0.0125452063
# 7   dsgdb9nsd_000002           2    H  0.9157893661  1.3587451950
# 8   dsgdb9nsd_000002           3    H -0.5202777357  1.3435321260
# 9   dsgdb9nsd_000003           0    O -0.0343604951  0.9775395708
# 10  dsgdb9nsd_000003           1    H  0.0647664923  0.0205721989
# 11  dsgdb9nsd_000003           2    H  0.8717903737  1.3007924050
# 12  dsgdb9nsd_000004           0    C  0.5995394918  0.0000000000
# 13  dsgdb9nsd_000004           1    C -0.5995394918  0.0000000000
# 14  dsgdb9nsd_000004           2    H -1.6616385860  0.0000000000
# 15  dsgdb9nsd_000004           3    H  1.6616385860  0.0000000000
# 16  dsgdb9nsd_000005           0    C -0.0133239314  1.1324657150
# 17  dsgdb9nsd_000005           1    N  0.0023107217 -0.0191585871
# 18  dsgdb9nsd_000005           2    H -0.0278026991  2.1989492960
# 19  dsgdb9nsd_000007           0    C -0.0187040036  1.5255820150
#
#                z    EN   rad  bond_lengths_mean  n_bonds
# 0   0.0080009958  2.55  0.82  1.091949701309204        4
# 1   0.0019761204  2.20  0.43  1.091953039169312        1
# 2   0.0002765748  2.20  0.43  1.091951608657837        1
# 3  -0.8766437152  2.20  0.43  1.091946363449097        1
# 4   0.9063972942  2.20  0.43  1.091947555541992        1
# 5   0.0625637998  3.04  0.80  1.017194986343384        3
# 6  -0.0273771593  2.20  0.43  1.017189979553223        1
# 7  -0.0287577581  2.20  0.43  1.017187237739563        1
# 8  -0.7755426124  2.20  0.43  1.017207860946655        1
# 9   0.0076015923  3.44  0.78  0.962106823921204        2
# 10  0.0015346341  2.20  0.43  0.962106823921204        1
# 11  0.0006931336  2.20  0.43  0.962106823921204        1
# 12  1.0000000000  2.55  0.82  1.130589008331299        2
# 13  1.0000000000  2.55  0.82  1.130589008331299        2
# 14  1.0000000000  2.20  0.43  1.062099099159241        1
# 15  1.0000000000  2.20  0.43  1.062099099159241        1
# 16  0.0082758861  2.55  0.82  1.109173059463501        2
# 17  0.0019287305  3.04  0.80  1.151747941970825        1
# 18  0.0141537903  2.20  0.43  1.066598057746887        1
# 19  0.0104328082  2.55  0.82  1.203627109527588        4

# %%
params = {'num_leaves': 128,
          'min_child_samples': 79,
          'objective': 'regression',
          'max_depth': 9,
          'learning_rate': 0.2,
          "boosting_type": "gbdt",
          "subsample_freq": 1,
          "subsample": 0.9,
          "bagging_seed": 11,
          "metric": 'mae',
          "verbosity": -1,
          'reg_alpha': 0.1,
          'reg_lambda': 0.3,
          'colsample_bytree': 1.0
         }
result_dict_lgb = train_model_regression(X=X, X_test=X_test, y=y, params=params, folds=folds, model_type='lgb', eval_metric='group_mae', plot_feature_importance=True,
                                                      verbose=500, early_stopping_rounds=200, n_estimators=5000)

# [500]	training's l1: 1.11007	valid_1's l1: 1.15256
# Out:
# Fold 1 started at Sat Jun  8 16:47:51 2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 1
2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 1.11374	valid_1's l1: 1.1599
# [1000]	training's l1: 0.98547	valid_1's l1: 1.06229
# [1500]	training's l1: 0.905904	valid_1's l1: 1.0086
# [2000]	training's l1: 0.848499	valid_1's l1: 0.974094
# [2500]	training's l1: 0.802688	valid_1's l1: 0.948787
# [3000]	training's l1: 0.764177	valid_1's l1: 0.929233
# [3500]	training's l1: 0.729741	valid_1's l1: 0.91203
# [4000]	training's l1: 0.700905	valid_1's l1: 0.899426
# [4500]	training's l1: 0.673978	valid_1's l1: 0.88752
# [5000]	training's l1: 0.650025	valid_1's l1: 0.878141
# Did not meet early stopping. Best iteration is:
# [5000]	training's l1: 0.650025	valid_1's l1: 0.878141
# CV mean score: -0.2800, std: 0.0027.

# %%
[
    'molecule_dist_max',
    'molecule_atom_1_dist_mean',
    'molecule_atom_index_0_y_1_max_diff',
    'molecule_couples',
    'molecule_atom_1_dist_std_diff',
    'molecule_type_dist_max',
    'molecule_dist_min',
    'molecule_type_dist_min',
    'molecule_atom_index_0_dist_std_div',
    'molecule_atom_index_1_dist_std_diff',
    'molecule_atom_index_0_dist_mean_div',
    'molecule_atom_index_1_dist_std_diff',
    'atom_index_1',
    'molecule_atom_index_0_dist_max_div',
    'molecule_atom_index_0_dist_max_diff',
    'molecule_type_0_dist_std_diff',
    'molecule_atom_index_0_dist_mean_diff',
    'molecule_atom_index_1_dist_std_diff',
    'molecule_type_dist_mean_diff',
]

# %%
good_columns = [
    'molecule_atom_index_0_dist_min',
    'molecule_atom_index_0_dist_max',
    'molecule_atom_index_0_dist_mean',
    'molecule_atom_index_0_dist_std',
    'y_0',
    'molecule_atom_index_0_y_1_std',
    'molecule_atom_index_1_dist_min',
    'molecule_atom_index_0_y_1_mean_div',
    'molecule_atom_index_0_z_1_std',
    'molecule_dist_mean',
    'molecule_atom_index_1_dist_std',
    'molecule_atom_index_0_x_1_std',
    'molecule_atom_index_1_dist_max',
    'molecule_atom_index_0_y_1_mean_diff',
    'molecule_atom_index_1_dist_mean',
]

# %%
sub['scalar_coupling_constant'] = result_dict_lgb['prediction']
sub.to_csv('../submissions/sub2.csv', index=False)
sub.head()
# Out:
#         id  scalar_coupling_constant
# 0  4658147        12.361512993735420
# 1  4658148       196.068743066744275
# 2  4658149         6.017216616205310
# 3  4658150       187.301426330745244
# 4  4658151         6.006984054660421

# %%
# %%time
# !kaggle competitions submit -c champs-scalar-coupling -f ../submissions/sub2.csv -m ""
# Out:
# 100%|██████████████████████████████████████| 64.0M/64.0M [00:15<00:00, 4.34MB/s]
# Successfully submitted to Predicting Molecular PropertiesCPU times: user 360 ms, sys: 544 ms, total: 904 ms
# Wall time: 20.4 s

# %%
from time import sleep
sleep(20)
# !kaggle competitions submissions -c champs-scalar-coupling
# Out:
# fileName  date                 description  status    publicScore  privateScore
# --------  -------------------  -----------  --------  -----------  ------------
# sub2.csv  2019-06-08 13:03:54  None         complete  -0.400       None
# sub1.csv  2019-06-04 16:51:51  None         complete  0.299        None

# %%
X.isnull().sum()
# Out:
# id                                       0
# molecule_name                            0
# atom_index_0                             0
# atom_index_1                             0
# type                                     0
# atom_0                                   0
# x_0                                      0
# y_0                                      0
# z_0                                      0
# atom_1                                   0
# x_1                                      0
# y_1                                      0
# z_1                                      0
# dist                                     0
# dist_x                                   0
# dist_y                                   0
# dist_z                                   0
# type_0                                   0
# type_1                                   0
# molecule_couples                         0
# molecule_dist_mean                       0
# molecule_dist_median                     0
# molecule_dist_min                        0
# molecule_dist_max                        0
# molecule_dist_std                        1
# molecule_dist_sum                        0
# molecule_dist_skew                      17
# atom_0_couples_count                     0
# atom_1_couples_count                     0
# type_0_couples_count                     0
#                                       ...
# molecule_type_0_dist_z_mean              0
# molecule_type_0_dist_z_mean_diff         0
# molecule_type_0_dist_z_mean_div          7
# molecule_type_0_dist_z_mean_sum          0
# molecule_type_0_dist_z_mean_mult         0
# molecule_type_0_dist_z_max               0
# molecule_type_0_dist_z_max_diff          0
# molecule_type_0_dist_z_max_div           7
# molecule_type_0_dist_z_max_sum           0
# molecule_type_0_dist_z_max_mult          0
# molecule_type_0_dist_z_std             342
# molecule_type_0_dist_z_std_diff        342
# molecule_type_0_dist_z_std_div         379
# molecule_type_0_dist_z_std_sum         342
# molecule_type_0_dist_z_std_mult        342
# molecule_type_0_dist_z_min               0
# molecule_type_0_dist_z_min_diff          0
# molecule_type_0_dist_z_min_div         751
# molecule_type_0_dist_z_min_sum           0
# molecule_type_0_dist_z_min_mult          0
# molecule_type_0_dist_z_skew           2126
# molecule_type_0_dist_z_skew_diff      2126
# molecule_type_0_dist_z_skew_div       2219
# molecule_type_0_dist_z_skew_sum       2126
# molecule_type_0_dist_z_skew_mult      2126
# molecule_type_0_dist_z_median            0
# molecule_type_0_dist_z_median_diff       0
# molecule_type_0_dist_z_median_div        7
# molecule_type_0_dist_z_median_sum        0
# molecule_type_0_dist_z_median_mult       0
# Length: 1107, dtype: int64

# %%
X_short = pd.DataFrame({'ind': list(X.index), 'type': X['type'].values, 'oof': [0] * len(X), 'target': y.values})
X_short_test = pd.DataFrame({'ind': list(X_test.index), 'type': X_test['type'].values, 'prediction': [0] * len(X_test)})
for t in X['type'].unique():
    print(f'Training of type {t}')
    X_t = X.loc[X['type'] == t]
    X_test_t = X_test.loc[X_test['type'] == t]
    y_t = X_short.loc[X_short['type'] == t, 'target']
    result_dict_lgb = train_model_regression(X=X_t, X_test=X_test_t, y=y_t, params=params, folds=folds, model_type='lgb', eval_metric='group_mae', plot_feature_importance=False,
                                                      verbose=500, early_stopping_rounds=200, n_estimators=2000)
    X_short.loc[X_short['type'] == t, 'oof'] = result_dict_lgb['oof']
    X_short_test.loc[X_short_test['type'] == t, 'prediction'] = result_dict_lgb['prediction']
    
sub['scalar_coupling_constant'] = X_short_test['prediction']
sub.to_csv('../submissions/sub2a.csv', index=False)
sub.head()
# Out:
# Training of type 0
# Fold 1 started at Sat Jun  8 18:37:36 2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 1.58509	valid_1's l1: 1.89447
# [1000]	training's l1: 1.27769	valid_1's l1: 1.77306
# [1500]	training's l1: 1.07884	valid_1's l1: 1.71715
# [2000]	training's l1: 0.929109	valid_1's l1: 1.6817
# Did not meet early stopping. Best iteration is:
# [2000]	training's l1: 0.929109	valid_1's l1: 1.6817
# Fold 2 started at Sat Jun  8 18:38:42 2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 1
# 4  4658151         6.238307645185175

# %%
# %%time
# !kaggle competitions submit -c champs-scalar-coupling -f ../submissions/sub2a.csv -m ""
# Out:
# 100%|██████████████████████████████████████| 64.0M/64.0M [00:58<00:00, 1.15MB/s]
# Successfully submitted to Predicting Molecular PropertiesCPU times: user 1.38 s, sys: 697 ms, total: 2.08 s
# Wall time: 1min 1s

# %%
from time import sleep
sleep(30)
# !kaggle competitions submissions -c champs-scalar-coupling
# Out:
# fileName   date                 description  status    publicScore  privateScore
# ---------  -------------------  -----------  --------  -----------  ------------
# sub2a.csv  2019-06-08 14:09:52  None         complete  -0.642       None
# sub2.csv   2019-06-08 13:03:54  None         complete  -0.400       None
# sub1.csv   2019-06-04 16:51:51  None         complete  0.299        None

# %%
X_short = pd.DataFrame({'ind': list(X.index), 'type': X['type'].values, 'oof': [0] * len(X), 'target': y.values})
X_short_test = pd.DataFrame({'ind': list(X_test.index), 'type': X_test['type'].values, 'prediction': [0] * len(X_test)})
for t in X['type'].unique():
    print(f'Training of type {t}')
    X_t = X.loc[X['type'] == t]
    X_test_t = X_test.loc[X_test['type'] == t]
    y_t = X_short.loc[X_short['type'] == t, 'target']
    result_dict_lgb = train_model_regression(X=X_t, X_test=X_test_t, y=y_t, params=params, folds=folds, model_type='lgb', eval_metric='group_mae', plot_feature_importance=False,
                                                      verbose=500, early_stopping_rounds=200, n_estimators=5000)
    X_short.loc[X_short['type'] == t, 'oof'] = result_dict_lgb['oof']
    X_short_test.loc[X_short_test['type'] == t, 'prediction'] = result_dict_lgb['prediction']
    
sub['scalar_coupling_constant'] = X_short_test['prediction']
sub.to_csv('../submissions/sub2b.csv', index=False)
sub.head()
# Out:
# Training of type 0
# Fold 1 started at Sat Jun  8 19:41:31 2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 1.58509	valid_1's l1: 1.89447
# [1000]	training's l1: 1.27713	valid_1's l1: 1.76987
# [1500]	training's l1: 1.07764	valid_1's l1: 1.7133
# [2000]	training's l1: 0.928753	valid_1's l1: 1.68058
# [2500]	training's l1: 0.810003	valid_1's l1: 1.65795
# [3000]	training's l1: 0.712973	valid_1's l1: 1.64237
# [3500]	training's l1: 0.632111	valid_1's l1: 1.63049
# [4000]	training's l1: 0.562913	valid_1's l1: 1.6211
# [4500]	training's l1: 0.503122	valid_1's l1: 1.61381
# [5000]	training's l1: 0.452217	valid_1's l1: 1.60851
# Did not meet early stopping. Best iteration is:
# [5000]	training's l1: 0.452217	valid_1's l1: 1.60851
# Fold 2 started at Sat Jun  8 19:45:03 2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 1.57697	valid_1's l1: 1.8863
# [1000]	training's l1: 1.2773	valid_1's l1: 1.76772
# [1500]	training's l1: 1.07565	valid_1's l1: 1.7109
# [2000]	training's l1: 0.926665	valid_1's l1: 1.67672
# [2500]	training's l1: 0.808031	valid_1's l1: 1.65318
# [3000]	training's l1: 0.711328	valid_1's l1: 1.63786
# [3500]	training's l1: 0.630829	valid_1's l1: 1.62619
# [4000]	training's l1: 0.561935	valid_1's l1: 1.6174
# [4500]	training's l1: 0.502359	valid_1's l1: 1.61066
# [5000]	training's l1: 0.450584	valid_1's l1: 1.6054
# Did not meet early stopping. Best iteration is:
# [5000]	training's l1: 0
2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 0.16146	valid_1's l1: 0.282154
# [1000]	training's l1: 0.100826	valid_1's l1: 0.268886
# [1500]	training's l1: 0.0670721	valid_1's l1: 0.263276
# [2000]	training's l1: 0.0462078	valid_1's l1: 0.260612
# [2500]	training's l1: 0.032623	valid_1's l1: 0.25926
# [3000]	training's l1: 0.0234011	valid_1's l1: 0.25832
# [3500]	training's l1: 0.0170254	valid_1's l1: 0.257712
# [4000]	training's l1: 0.0125753	valid_1's l1: 0.257331
# [4500]	training's l1: 0.00945534	valid_1's l1: 0.257091
# [5000]	training's l1: 0.00730657	valid_1's l1: 0.256943
# Did not meet early stopping. Best iteration is:
# [5000]	training's l1: 0.00730657	valid_1's l1: 0.256943
# Fold 4 started at Sat Jun  8 21:34:56 2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 0.161444	valid_1's l1: 0.281048
# [1000]	training's l1: 0.0998889	valid_1's l1: 0.267082
# [1500]	training's l1: 0.0666925	valid_1's l1: 0.2615
# [2000]	training's l1: 0.0459436	valid_1's l1: 0.258853
# [2500]	training's l1: 0.0321573	valid_1's l1: 0.257338
# [3000]	training's l1: 0.0230317	valid_1's l1: 0.256559
# [3500]	training's l1: 0.0167489	valid_1's l1: 0.256087
# [4000]	training's l1: 0.0124032	valid_1's l1: 0.25579
# [4500]	training's l1: 0.0093713	valid_1's l1: 0.255571
# [5000]	training's l1: 0.00726102	valid_1's l1: 0.255438
# Did not meet early stopping. Best iteration is:
# [5000]	training's l1: 0.00726102	valid_1's l1: 0.255438
# Fold 5 started at Sat Jun  8 21:36:08 2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's l1: 0.159512	valid_1's l1: 0.279751
# [1000]	training's l1: 0.100237	valid_1's l1: 0.266151
# [1500]	training's l1: 0.0672467	valid_1's l1: 0.261057
# [2000]	training's l1: 0.0464822	valid_1's l1: 0.258545
# [2500]	training's l1: 0.0326767	valid_1's l1: 0.25696
# [3000]	training's l1: 0.0233154	valid_1's l1: 0.256113
# [3500]	training's l1: 0.0169018	valid_1's l1: 0.255692
# [4000]	training's l1: 0.0125353	valid_1's l1: 0.255383
# [4500]	training's l1: 0.00946305	valid_1's l1: 0.255208
# [5000]	training's l1: 0.00730133	valid_1's l1: 0.255051
# Did not meet early stopping. Best iteration is:
# [5000]	training's l1: 0.00730133	valid_1's l1: 0.255051
# CV mean score: -1.3633, std: 0.0027.
#         id  scalar_coupling_constant
# 0  4658147         5.698773512149136
# 1  4658148       193.099534343141073
# 2  4658149         5.571093461035416
# 3  4658150       184.148645478728781
# 4  4658151         6.021901072053419

# %%
# %%time
# !kaggle competitions submit -c champs-scalar-coupling -f ../submissions/sub2b.csv -m ""
# Out:
# 100%|██████████████████████████████████████| 64.0M/64.0M [00:18<00:00, 3.63MB/s]
# Successfully submitted to Predicting Molecular PropertiesCPU times: user 431 ms, sys: 547 ms, total: 978 ms
# Wall time: 21.4 s

# %%
from time import sleep
sleep(30)
# !kaggle competitions submissions -c champs-scalar-coupling
# Out:
# fileName   date                 description  status    publicScore  privateScore
# ---------  -------------------  -----------  --------  -----------  ------------
# sub2b.csv  2019-06-08 17:53:30  None         complete  -0.690       None
# sub2a.csv  2019-06-08 14:09:52  None         complete  -0.642       None
# sub2.csv   2019-06-08 13:03:54  None         complete  -0.400       None
# sub1.csv   2019-06-04 16:51:51  None         complete  0.299        None
